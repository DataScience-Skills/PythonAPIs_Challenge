# %% [markdown]
# # Vacation Weather:
# ### To collect, visualize, and analyze weather data for more than 500 cities around the world
# ---
# #### __Note__: Educational Material
# - _This project is intended as reference and educational material; expect extensive code documentation_
# ---

# %%
# Import Dependencies - this is analogous setting the table with utensils and silverware before eating dinner; you're bringing the necessary tools.
import sys # Importing system-specific parameters and functions
sys.path.append('script/')  # Add the 'script/' directory to the list of paths to search for modules
try:
    import kaleido # for exporting Plotly plots to static image formats like PNG, JPEG, etc.
    print("kaleido is already installed.")
except ImportError:
    print("Installing kaleido...")
    # !pip install kaleido
import matplotlib.pyplot as plt # for plotting graphs and charts. Uses [plt] as an alias.
import plotly.express as px # for making interactive, publication-quality graphs. [plotly.express] is a simpler interface. Uses [px] as an alias.
import plotly.graph_objects as go # for creating interactive visualizations with more control over the individual elements. Uses [go] as an alias.
from scipy.optimize import curve_fit # for curve fitting and parameter estimation in nonlinear regression.
import pandas as pd # for data manipulation and analysis. Uses [pd] as an alias.
import numpy as np # for numerical computations. Uses [np] as an alias.
import requests # to make HTTP requests, useful for APIs.
import time # for time-related tasks like pausing code execution.
import hvplot.pandas as hvpd # for interactive plotting directly with Pandas DataFrames, uses HoloViews for rendering. Uses [hvpd] as an alias.
import os # for interacting with the operating system. Provides functions to navigate, create, delete and modify files and directories.
from citipy import citipy # for finding the nearest city given latitude and longitude coordinates data.
from scipy.stats import linregress # for calculating linear regression
from api_keys import weather_api_key, geoapify_key  # imports both [weather_api_key] and [geoapify_key] from another Python file.

print("Dependencies installed and imported") # Confirmation that cell executed successfully
# Out:
# kaleido is already installed.
# Dependencies installed and imported

# %% [markdown]
# ---
# ### Generate a list of cities

# %%
# Initialize Variables
lat_lngs = [] # list for holding latitude and longitude coordinates combinations
cities = [] # list for holding cities names

# Define the range of possible latitude and longitude values
lat_range = (-90, 90) # tuple for storing lat_range as a tuple as we want this variable to be constant
lng_range = (-180, 180) # tuple for storing lng_range as a tuple as we want this variable to be constant

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500) # Generates 1500 random latitude values
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500) # Generates 1500 random latitude values
lat_lngs = zip(lats, lngs) # Combines two arrays ([lats] and [lngs]) into one iterable of tuple elements (e.g. -35.4, 117.2)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name # assigns the city closest to the coordinates to a variable, [city]
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 614

# %% [markdown]
# ---
# ### Use the OpenWeatherMap API to retrieve weather data from the cities in the [cities] list

# %%
# Initialize Variables
url = "http://api.openweathermap.org/data/2.5/weather?" # variable for the API base URl. Append to this parameters and api key.
list_city_data = [] # list for holding the weather data for each city

# Print to logger
print("Beginning Data Retrieval     ") # output aesthetic title for logging API requested data
print("-----------------------------") # output aesthetic ---- for logging API requested data

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for index, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (index % 50 == 0 and index >= 50): # This conditional if statment causes the code execution to pause for 1 second every 50 iterations
        set_count += 1
        record_count = 0
        time.sleep(1) # This helps orevent rate-limiting by the API if it has restrictions on frequency of requests

    # Create endpoint URL with each city
    city_url = url + "q=" + city + "&appid=" + weather_api_key # variable for the API endpoint URL. Used to request the data.
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city)) # output tracking index and returned city value

    # Add 1 to the record count
    record_count += 1 # to progress iteratively through the for loop

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json() # variable for the retrieved data. Stored in json datatype format.

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into the [city_data] list
        list_city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------") # output aesthetic ---- for logging API requested data
print("Data Retrieval Complete      ") # output aesthetic conclusive statement for logging API requested data
print("-----------------------------") # output aesthetic ---- for logging API requested data
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | havre
# Processing Record 3 of Set 1 | thompson
# Processing Record 4 of Set 1 | rondonopolis
# Processing Record 5 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | albany
# Processing Record 8 of Set 1 | mercedes
# Processing Record 9 of Set 1 | westport
# Processing Record 10 of Set 1 | limon
# Processing Record 11 of Set 1 | clyde river
# Processing Record 12 of Set 1 | hasaki
# Processing Record 13 of Set 1 | puerto ayora
# Processing Record 14 of Set 1 | aklavik
# Processing Record 15 of Set 1 | linxia
# Processing Record 16 of Set 1 | upernavik
# Processing Record 17 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | tasiilaq
# Processing Record 20 of Set 1 | souillac
# Processing Record 21 of Set 1 | esperance
# Processing Record 22 of Set 1 | mar del plata
# Processing Record 23 of Set 1 | kodiak
# Processing Record 24 of Set 1 | hilo
# Processing Record 25 of Set 1 | sorland
# Processing Record 26 of Set 1 | dwarka
# Processing Record 27 of Set 1 | orthez
# Processing Record 28 of Set 1 | busselton
# Processing Record 29 of Set 1 | lavrentiya
# Processing Record 30 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 1 | saint-philippe
# Processing Record 32 of Set 1 | pontal do parana
# Processing Record 33 of Set 1 | punta arenas
# Processing Record 34 of Set 1 | north myrtle beach
# Processing Record 35 of Set 1 | faanui
# Processing Record 36 of Set 1 | cape town
# Processing Record 37 of Set 1 | jieshi
# Processing Record 38 of Set 1 | mahebourg
# Processing Record 39 of Set 1 | saskylakh
# Processing Record 40 of Set 1 | cayenne
# Processing Record 41 of Set 1 | arraial do cabo
# Processing Record 42 of Set 1 | moroni
# Processing Record 43 of Set 1 | jamestown
# Processing Record 44 of Set 1 | haverfordwest
# Processing Record 45 of Set 1 | andevoranto
# City not found. Skipping...
# Processing Record 46 of Set 1 | lodja
# Processing Record 47 of Set 1 | marshall
# Processing Record 48 of Set 1 | kangaatsiaq
# Processing Record 49 of Set 1 | moron
# Processing Record 50 of Set 1 | kapaa
# Processing Record 0 of Set 2 | torbay
# Processing Record 1 of Set 2 | east london
# Processing Record 2 of Set 2 | sassari
# Processing Record 3 of Set 2 | surt
# Processing Record 4 of Set 2 | atuona
# Processing Record 5 of Set 2 | castro
# Processing Record 6 of Set 2 | sisimiut
# Processing Record 7 of Set 2 | tiksi
# Processing Record 8 of Set 2 | bluff
# Processing Record 9 of Set 2 | honiara
# Processing Record 10 of Set 2 | igarka
# Processing Record 11 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 2 | hobart
# Processing Record 13 of Set 2 | cabo san lucas
# Processing Record 14 of Set 2 | padang
# Processing Record 15 of Set 2 | hermanus
# Processing Record 16 of Set 2 | tuktoyaktuk
# Processing Record 17 of Set 2 | quelimane
# Processing Record 18 of Set 2 | yerofey pavlovich
# Processing Record 19 of Set 2 | constitucion
# Processing Record 20 of Set 2 | port alfred
# Processing Record 21 of Set 2 | turukhansk
# Processing Record 22 of Set 2 | lagoa
# Processing Record 23 of Set 2 | ardistan
# City not found. Skipping...
# Processing Record 24 of Set 2 | zhangye
# Processing Record 25 of Set 2 | barrow
# Processing Record 26 of Set 2 | vardo
# Processing Record 27 of Set 2 | nome
# Processing Record 28 of Set 2 | cherdyn
# Processing Record 29 of Set 2 | bonavista
# Processing Record 30 of Set 2 | rancho palos verdes
# Processing Record 31 of Set 2 | ribas do rio pardo
# Processing Record 32 of Set 2 | am timan
# Processing Record 33 of Set 2 | douglas
# Processing Record 34 of Set 2 | svetlaya
# Processing Record 35 of Set 2 | beringovskiy
# Processing Record 36 of Set 2 | oranjestad
# Processing Record 37 of Set 2 | carnarvon
# Processing Record 38 of Set 2 | kizhinga
# Processing Record 39 of Set 2 | bredasdorp
# Processing Record 40 of Set 2 | kalilangan
# Processing Record 41 of Set 2 | buenos aires
# Processing Record 42 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 43 of Set 2 | madang
# Processing Record 44 of Set 2 | sovetskiy
# Processing Record 45 of Set 2 | victoria
# Processing Record 46 of Set 2 | chuy
# Processing Record 47 of Set 2 | kudahuvadhoo
# Processing Record 48 of Set 2 | mildura
# Processing Record 49 of Set 2 | honningsvag
# Processing Record 0 of Set 3 | vokhtoga
# Processing Record 1 of Set 3 | samarai
# Processing Record 2 of Set 3 | sivas
# Processing Record 3 of Set 3 | garoua
# Processing Record 4 of Set 3 | ilulissat
# Processing Record 5 of Set 3 | manikganj
# Processing Record 6 of Set 3 | luderitz
# Processing Record 7 of Set 3 | severo-kurilsk
# Processing Record 8 of Set 3 | sitka
# Processing Record 9 of Set 3 | katsuura
# Processing Record 10 of Set 3 | talnakh
# Processing Record 11 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 12 of Set 3 | bengkulu
# Processing Record 13 of Set 3 | anadyr
# Processing Record 14 of Set 3 | port keats
# Processing Record 15 of Set 3 | weihe
# Processing Record 16 of Set 3 | sola
# Processing Record 17 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 3 | cidreira
# Processing Record 19 of Set 3 | los angeles
# Processing Record 20 of Set 3 | georgetown
# Processing Record 21 of Set 3 | porto velho
# Processing Record 22 of Set 3 | yellowknife
# Processing Record 23 of Set 3 | buala
# Processing Record 24 of Set 3 | taltal
# Processing Record 25 of Set 3 | lebu
# Processing Record 26 of Set 3 | malabo
# Processing Record 27 of Set 3 | antalaha
# Processing Record 28 of Set 3 | chas
# Processing Record 29 of Set 3 | havelock
# Processing Record 30 of Set 3 | comodoro rivadavia
# Processing Record 31 of Set 3 | didsbury
# Processing Record 32 of Set 3 | deputatskiy
# Processing Record 33 of Set 3 | bambous virieux
# Processing Record 34 of Set 3 | fortuna
# Processing Record 35 of Set 3 | mehamn
# Processing Record 36 of Set 3 | teahupoo
# Processing Record 37 of Set 3 | dingle
# Processing Record 38 of Set 3 | kavaratti
# Processing Record 39 of Set 3 | sao lourenco do sul
# Processing Record 40 of Set 3 | weligama
# Processing Record 41 of Set 3 | wajir
# Processing Record 42 of Set 3 | dikson
# Processing Record 43 of Set 3 | suifenhe
# Processing Record 44 of Set 3 | atar
# Processing Record 45 of Set 3 | garmsar
# Processing Record 46 of Set 3 | vaini
# Processing Record 47 of Set 3 | kaitangata
# Processing Record 48 of Set 3 | tiznit
# Processing Record 49 of Set 3 | kawalu
# Processing Record 0 of Set 4 | qaanaaq
# Processing Record 1 of Set 4 | kieta
# Processing Record 2 of Set 4 | nikolskoye
# Processing Record 3 of Set 4 | bay roberts
# Processing Record 4 of Set 4 | kashi
# Processing Record 5 of Set 4 | ribeira grande
# Processing Record 6 of Set 4 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 4 | butaritari
# Processing Record 8 of Set 4 | caravelas
# Processing Record 9 of Set 4 | amuntai
# Processing Record 10 of Set 4 | norman wells
# Processing Record 11 of Set 4 | ponta do sol
# Processing Record 12 of Set 4 | tomohon
# Processing Record 13 of Set 4 | costa rica
# Processing Record 14 of Set 4 | areosa
# Processing Record 15 of Set 4 | makakilo city
# Processing Record 16 of Set 4 | katy
# Processing Record 17 of Set 4 | namibe
# Processing Record 18 of Set 4 | krasnoselkup
# Processing Record 19 of Set 4 | kizner
# Processing Record 20 of Set 4 | eldorado
# Processing Record 21 of Set 4 | pimentel
# Processing Record 22 of Set 4 | port elizabeth
# Processing Record 23 of Set 4 | coihaique
# Processing Record 24 of Set 4 | lata
# Processing Record 25 of Set 4 | olafsvik
# Processing Record 26 of Set 4 | marfino
# Processing Record 27 of Set 4 | hithadhoo
# Processing Record 28 of Set 4 | oranjemund
# Processing Record 29 of Set 4 | asosa
# Processing Record 30 of Set 4 | marawi
# Processing Record 31 of Set 4 | saint george
# Processing Record 32 of Set 4 | hami
# Processing Record 33 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 4 | bariadi
# Processing Record 35 of Set 4 | hassleholm
# Processing Record 36 of Set 4 | alyangula
# Processing Record 37 of Set 4 | collie
# Processing Record 38 of Set 4 | nioro
# Processing Record 39 of Set 4 | pangani
# Processing Record 40 of Set 4 | bambanglipuro
# Processing Record 41 of Set 4 | acari
# Processing Record 42 of Set 4 | tuatapere
# Processing Record 43 of Set 4 | sur
# Processing Record 44 of Set 4 | hovd
# Processing Record 45 of Set 4 | longyan
# Processing Record 46 of Set 4 | chimoio
# Processing Record 47 of Set 4 | yakeshi
# Processing Record 48 of Set 4 | verkhnevilyuysk
# Processing Record 49 of Set 4 | san patricio
# Processing Record 0 of Set 5 | gorontalo
# Processing Record 1 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 2 of Set 5 | akyab
# Processing Record 3 of Set 5 | umm durman
# City not found. Skipping...
# Processing Record 4 of Set 5 | gulshat
# City not found. Skipping...
# Processing Record 5 of Set 5 | sao filipe
# Processing Record 6 of Set 5 | hulan
# Processing Record 7 of Set 5 | hornepayne
# Processing Record 8 of Set 5 | hurghada
# Processing Record 9 of Set 5 | bogen
# Processing Record 10 of Set 5 | maneadero
# Processing Record 11 of Set 5 | bekhtery
# Processing Record 12 of Set 5 | khatanga
# Processing Record 13 of Set 5 | barsesti
# City not found. Skipping...
# Processing Record 14 of Set 5 | shatsk
# Processing Record 15 of Set 5 | purranque
# Processing Record 16 of Set 5 | margate
# Processing Record 17 of Set 5 | codrington
# Processing Record 18 of Set 5 | potosi
# Processing Record 19 of Set 5 | yulara
# Processing Record 20 of Set 5 | new norfolk
# Processing Record 21 of Set 5 | iqaluit
# Processing Record 22 of Set 5 | umm kaddadah
# Processing Record 23 of Set 5 | balkanabat
# Processing Record 24 of Set 5 | saldanha
# Processing Record 25 of Set 5 | saint-pierre
# Processing Record 26 of Set 5 | paamiut
# Processing Record 27 of Set 5 | vila franca do campo
# Processing Record 28 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 29 of Set 5 | lensk
# Processing Record 30 of Set 5 | emerald
# Processing Record 31 of Set 5 | russell
# Processing Record 32 of Set 5 | maceio
# Processing Record 33 of Set 5 | tucuman
# Processing Record 34 of Set 5 | avera
# Processing Record 35 of Set 5 | abengourou
# Processing Record 36 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 5 | touros
# Processing Record 38 of Set 5 | avarua
# Processing Record 39 of Set 5 | tabas
# Processing Record 40 of Set 5 | san cristobal
# Processing Record 41 of Set 5 | mount gambier
# Processing Record 42 of Set 5 | nemuro
# Processing Record 43 of Set 5 | guerrero negro
# Processing Record 44 of Set 5 | marsh harbour
# Processing Record 45 of Set 5 | ambon
# Processing Record 46 of Set 5 | lazaro cardenas
# Processing Record 47 of Set 5 | horki
# Processing Record 48 of Set 5 | kruisfontein
# Processing Record 49 of Set 5 | oksfjord
# Processing Record 0 of Set 6 | shatoy
# Processing Record 1 of Set 6 | broome
# Processing Record 2 of Set 6 | longyearbyen
# Processing Record 3 of Set 6 | salalah
# Processing Record 4 of Set 6 | snezhnogorsk
# Processing Record 5 of Set 6 | hirara
# Processing Record 6 of Set 6 | guiratinga
# Processing Record 7 of Set 6 | kasama
# Processing Record 8 of Set 6 | ames
# Processing Record 9 of Set 6 | esmeraldas
# Processing Record 10 of Set 6 | kavieng
# Processing Record 11 of Set 6 | saint-francois
# Processing Record 12 of Set 6 | ahipara
# Processing Record 13 of Set 6 | sioux lookout
# Processing Record 14 of Set 6 | huangyan
# Processing Record 15 of Set 6 | pochutla
# Processing Record 16 of Set 6 | daru
# Processing Record 17 of Set 6 | jinxiang
# Processing Record 18 of Set 6 | sabha
# Processing Record 19 of Set 6 | lasa
# Processing Record 20 of Set 6 | chokurdakh
# Processing Record 21 of Set 6 | sobolevo
# Processing Record 22 of Set 6 | hofn
# Processing Record 23 of Set 6 | thinadhoo
# Processing Record 24 of Set 6 | cherskiy
# Processing Record 25 of Set 6 | leua
# Processing Record 26 of Set 6 | benjamin constant
# Processing Record 27 of Set 6 | fort saint john
# City not found. Skipping...
# Processing Record 28 of Set 6 | jalu
# Processing Record 29 of Set 6 | san jose
# Processing Record 30 of Set 6 | vila velha
# Processing Record 31 of Set 6 | yumen
# Processing Record 32 of Set 6 | bhuj
# Processing Record 33 of Set 6 | tarudant
# City not found. Skipping...
# Processing Record 34 of Set 6 | lahad datu
# Processing Record 35 of Set 6 | brownfield
# Processing Record 36 of Set 6 | masuguru
# Processing Record 37 of Set 6 | matagami
# Processing Record 38 of Set 6 | ipixuna
# Processing Record 39 of Set 6 | pitimbu
# Processing Record 40 of Set 6 | champerico
# Processing Record 41 of Set 6 | isangel
# Processing Record 42 of Set 6 | port hedland
# Processing Record 43 of Set 6 | kamaishi
# Processing Record 44 of Set 6 | umm lajj
# Processing Record 45 of Set 6 | batagay-alyta
# Processing Record 46 of Set 6 | hobyo
# Processing Record 47 of Set 6 | pointe-noire
# Processing Record 48 of Set 6 | tibiri
# Processing Record 49 of Set 6 | indianola
# Processing Record 0 of Set 7 | portland
# Processing Record 1 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 7 | burns lake
# Processing Record 3 of Set 7 | kota belud
# Processing Record 4 of Set 7 | komsomolskiy
# Processing Record 5 of Set 7 | senmonorom
# City not found. Skipping...
# Processing Record 6 of Set 7 | wanaka
# Processing Record 7 of Set 7 | xiangdong
# City not found. Skipping...
# Processing Record 8 of Set 7 | crisan
# Processing Record 9 of Set 7 | inta
# Processing Record 10 of Set 7 | mendoza
# Processing Record 11 of Set 7 | cancun
# Processing Record 12 of Set 7 | alofi
# Processing Record 13 of Set 7 | dauphin
# Processing Record 14 of Set 7 | flinders
# Processing Record 15 of Set 7 | olga
# Processing Record 16 of Set 7 | saint anthony
# Processing Record 17 of Set 7 | jiddah
# City not found. Skipping...
# Processing Record 18 of Set 7 | vaasa
# Processing Record 19 of Set 7 | candolim
# Processing Record 20 of Set 7 | rio grande
# Processing Record 21 of Set 7 | general pico
# Processing Record 22 of Set 7 | los llanos de aridane
# Processing Record 23 of Set 7 | richards bay
# Processing Record 24 of Set 7 | tamiahua
# Processing Record 25 of Set 7 | new lenox
# Processing Record 26 of Set 7 | leningradskiy
# Processing Record 27 of Set 7 | plettenberg bay
# Processing Record 28 of Set 7 | ranong
# Processing Record 29 of Set 7 | formoso do araguaia
# City not found. Skipping...
# Processing Record 30 of Set 7 | lamesa
# Processing Record 31 of Set 7 | pousat
# City not found. Skipping...
# Processing Record 32 of Set 7 | filingue
# Processing Record 33 of Set 7 | ostrovnoy
# Processing Record 34 of Set 7 | kokopo
# Processing Record 35 of Set 7 | itarema
# Processing Record 36 of Set 7 | andreyevo
# Processing Record 37 of Set 7 | mitsamiouli
# Processing Record 38 of Set 7 | teguldet
# Processing Record 39 of Set 7 | aquiraz
# Processing Record 40 of Set 7 | beirut
# Processing Record 41 of Set 7 | bokspits
# City not found. Skipping...
# Processing Record 42 of Set 7 | ancud
# Processing Record 43 of Set 7 | huarmey
# Processing Record 44 of Set 7 | chebsara
# Processing Record 45 of Set 7 | raha
# Processing Record 46 of Set 7 | kharabali
# Processing Record 47 of Set 7 | kousseri
# Processing Record 48 of Set 7 | qobustan
# Processing Record 49 of Set 7 | lufilufi
# Processing Record 0 of Set 8 | corrente
# Processing Record 1 of Set 8 | ekhabi
# Processing Record 2 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 8 | yaan
# Processing Record 4 of Set 8 | tiarei
# Processing Record 5 of Set 8 | meulaboh
# Processing Record 6 of Set 8 | lipari
# Processing Record 7 of Set 8 | sangar
# Processing Record 8 of Set 8 | gilazi
# City not found. Skipping...
# Processing Record 9 of Set 8 | sayyan
# Processing Record 10 of Set 8 | japura
# Processing Record 11 of Set 8 | peniche
# Processing Record 12 of Set 8 | klaksvik
# Processing Record 13 of Set 8 | puerto montt
# Processing Record 14 of Set 8 | takoradi
# Processing Record 15 of Set 8 | tabou
# Processing Record 16 of Set 8 | severnyy-kospashskiy
# Processing Record 17 of Set 8 | bagdarin
# Processing Record 18 of Set 8 | vammala
# Processing Record 19 of Set 8 | kloulklubed
# Processing Record 20 of Set 8 | beboto
# Processing Record 21 of Set 8 | dunedin
# Processing Record 22 of Set 8 | knin
# Processing Record 23 of Set 8 | roma
# Processing Record 24 of Set 8 | hoopstad
# Processing Record 25 of Set 8 | radcliff
# Processing Record 26 of Set 8 | qui nhon
# Processing Record 27 of Set 8 | humaita
# Processing Record 28 of Set 8 | tomatlan
# Processing Record 29 of Set 8 | antofagasta
# Processing Record 30 of Set 8 | mana
# Processing Record 31 of Set 8 | camana
# Processing Record 32 of Set 8 | alice springs
# Processing Record 33 of Set 8 | bowen
# Processing Record 34 of Set 8 | oliveira dos brejinhos
# Processing Record 35 of Set 8 | uyuni
# Processing Record 36 of Set 8 | redcar
# Processing Record 37 of Set 8 | aquidauana
# Processing Record 38 of Set 8 | grindavik
# Processing Record 39 of Set 8 | camargo
# Processing Record 40 of Set 8 | jonuta
# Processing Record 41 of Set 8 | mackay
# Processing Record 42 of Set 8 | mwinilunga
# Processing Record 43 of Set 8 | jujuy
# City not found. Skipping...
# Processing Record 44 of Set 8 | mpika
# Processing Record 45 of Set 8 | alepe
# Processing Record 46 of Set 8 | boyolangu
# Processing Record 47 of Set 8 | martaban
# Processing Record 48 of Set 8 | kirovskiy
# Processing Record 49 of Set 8 | nantucket
# Processing Record 0 of Set 9 | waipawa
# Processing Record 1 of Set 9 | laguna
# Processing Record 2 of Set 9 | lixourion
# Processing Record 3 of Set 9 | wattegama
# Processing Record 4 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 5 of Set 9 | monaragala
# Processing Record 6 of Set 9 | chibombo
# Processing Record 7 of Set 9 | lorengau
# Processing Record 8 of Set 9 | rocha
# Processing Record 9 of Set 9 | almeirim
# Processing Record 10 of Set 9 | yerbogachen
# Processing Record 11 of Set 9 | saint-louis
# Processing Record 12 of Set 9 | los algarrobos
# Processing Record 13 of Set 9 | ossora
# Processing Record 14 of Set 9 | pangody
# Processing Record 15 of Set 9 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 16 of Set 9 | hokitika
# Processing Record 17 of Set 9 | fray bentos
# Processing Record 18 of Set 9 | acurenam
# Processing Record 19 of Set 9 | dinard
# Processing Record 20 of Set 9 | srednekolymsk
# Processing Record 21 of Set 9 | qingdao
# Processing Record 22 of Set 9 | christchurch
# Processing Record 23 of Set 9 | chikoy
# City not found. Skipping...
# Processing Record 24 of Set 9 | the valley
# Processing Record 25 of Set 9 | bandar
# Processing Record 26 of Set 9 | crabtree
# Processing Record 27 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 28 of Set 9 | dinghai
# Processing Record 29 of Set 9 | yar-sale
# Processing Record 30 of Set 9 | neubrandenburg
# Processing Record 31 of Set 9 | provideniya
# Processing Record 32 of Set 9 | monrovia
# Processing Record 33 of Set 9 | krasnoye
# Processing Record 34 of Set 9 | kachiry
# Processing Record 35 of Set 9 | amahai
# Processing Record 36 of Set 9 | airai
# Processing Record 37 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 9 | mumford
# Processing Record 39 of Set 9 | dicabisagan
# Processing Record 40 of Set 9 | bajina basta
# Processing Record 41 of Set 9 | celestun
# Processing Record 42 of Set 9 | ketchikan
# Processing Record 43 of Set 9 | anqing
# Processing Record 44 of Set 9 | disna
# Processing Record 45 of Set 9 | presidencia roque saenz pena
# Processing Record 46 of Set 9 | bismarck
# Processing Record 47 of Set 9 | bara
# Processing Record 48 of Set 9 | mareeba
# Processing Record 49 of Set 9 | nanortalik
# Processing Record 0 of Set 10 | evensk
# Processing Record 1 of Set 10 | bethel
# Processing Record 2 of Set 10 | paucartambo
# City not found. Skipping...
# Processing Record 3 of Set 10 | great falls
# Processing Record 4 of Set 10 | chase
# Processing Record 5 of Set 10 | knysna
# Processing Record 6 of Set 10 | zyryanovsk
# Processing Record 7 of Set 10 | tsnori
# Processing Record 8 of Set 10 | san vicente
# Processing Record 9 of Set 10 | moissala
# Processing Record 10 of Set 10 | sterling
# Processing Record 11 of Set 10 | yigou
# Processing Record 12 of Set 10 | suntar
# Processing Record 13 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 14 of Set 10 | khandyga
# Processing Record 15 of Set 10 | katha
# City not found. Skipping...
# Processing Record 16 of Set 10 | liwale
# Processing Record 17 of Set 10 | kharagauli
# Processing Record 18 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 19 of Set 10 | belmonte
# Processing Record 20 of Set 10 | sao joao da barra
# Processing Record 21 of Set 10 | marivan
# Processing Record 22 of Set 10 | ust-nera
# Processing Record 23 of Set 10 | korla
# Processing Record 24 of Set 10 | palaikastron
# Processing Record 25 of Set 10 | adelaide
# Processing Record 26 of Set 10 | ponta delgada
# Processing Record 27 of Set 10 | salym
# Processing Record 28 of Set 10 | taraz
# Processing Record 29 of Set 10 | nador
# Processing Record 30 of Set 10 | warrnambool
# Processing Record 31 of Set 10 | vurgun
# Processing Record 32 of Set 10 | baboua
# City not found. Skipping...
# Processing Record 33 of Set 10 | garden city
# Processing Record 34 of Set 10 | terrasini
# Processing Record 35 of Set 10 | aneho
# Processing Record 36 of Set 10 | santa cruz
# Processing Record 37 of Set 10 | anito
# Processing Record 38 of Set 10 | ola
# Processing Record 39 of Set 10 | zhigansk
# Processing Record 40 of Set 10 | soyo
# Processing Record 41 of Set 10 | west bay
# Processing Record 42 of Set 10 | port lincoln
# Processing Record 43 of Set 10 | kadykchan
# City not found. Skipping...
# Processing Record 44 of Set 10 | atsiki
# City not found. Skipping...
# Processing Record 45 of Set 10 | barcelos
# Processing Record 46 of Set 10 | sedalia
# Processing Record 47 of Set 10 | gigmoto
# Processing Record 48 of Set 10 | warah
# Processing Record 49 of Set 10 | kidal
# Processing Record 0 of Set 11 | dolinsk
# Processing Record 1 of Set 11 | peterborough
# Processing Record 2 of Set 11 | san bernardo
# Processing Record 3 of Set 11 | goma
# Processing Record 4 of Set 11 | porto novo
# Processing Record 5 of Set 11 | serro
# Processing Record 6 of Set 11 | hoi an
# Processing Record 7 of Set 11 | shimoda
# Processing Record 8 of Set 11 | udachnyy
# Processing Record 9 of Set 11 | hellin
# Processing Record 10 of Set 11 | yuncheng
# Processing Record 11 of Set 11 | axim
# Processing Record 12 of Set 11 | jorochito
# Processing Record 13 of Set 11 | frutigen
# Processing Record 14 of Set 11 | ucluelet
# Processing Record 15 of Set 11 | pedasi
# Processing Record 16 of Set 11 | yei
# Processing Record 17 of Set 11 | uvira
# Processing Record 18 of Set 11 | pangnirtung
# Processing Record 19 of Set 11 | kiunga
# Processing Record 20 of Set 11 | alta floresta
# Processing Record 21 of Set 11 | amga
# Processing Record 22 of Set 11 | carballo
# Processing Record 23 of Set 11 | isetskoye
# Processing Record 24 of Set 11 | ormara
# Processing Record 25 of Set 11 | camacupa
# Processing Record 26 of Set 11 | beberibe
# Processing Record 27 of Set 11 | bacolod
# Processing Record 28 of Set 11 | humberto de campos
# Processing Record 29 of Set 11 | beisfjord
# Processing Record 30 of Set 11 | gat
# Processing Record 31 of Set 11 | uspenka
# Processing Record 32 of Set 11 | hambantota
# Processing Record 33 of Set 11 | paso de los toros
# Processing Record 34 of Set 11 | poum
# Processing Record 35 of Set 11 | lompoc
# Processing Record 36 of Set 11 | pisco
# Processing Record 37 of Set 11 | yining
# Processing Record 38 of Set 11 | syracuse
# Processing Record 39 of Set 11 | tahoua
# Processing Record 40 of Set 11 | mattru
# Processing Record 41 of Set 11 | brae
# Processing Record 42 of Set 11 | vallenar
# Processing Record 43 of Set 11 | amderma
# City not found. Skipping...
# Processing Record 44 of Set 11 | indiana
# Processing Record 45 of Set 11 | ofunato
# Processing Record 46 of Set 11 | baruun-urt
# Processing Record 47 of Set 11 | moose factory
# Processing Record 48 of Set 11 | vestmannaeyjar
# Processing Record 49 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 0 of Set 12 | samfya
# Processing Record 1 of Set 12 | kurilsk
# Processing Record 2 of Set 12 | miri
# Processing Record 3 of Set 12 | ambilobe
# Processing Record 4 of Set 12 | zhigalovo
# Processing Record 5 of Set 12 | tazovskiy
# Processing Record 6 of Set 12 | dzilam gonzalez
# Processing Record 7 of Set 12 | lamar
# Processing Record 8 of Set 12 | ondorhaan
# City not found. Skipping...
# Processing Record 9 of Set 12 | chicama
# Processing Record 10 of Set 12 | pevek
# Processing Record 11 of Set 12 | trzcianka
# Processing Record 12 of Set 12 | imeni poliny osipenko
# Processing Record 13 of Set 12 | aykhal
# Processing Record 14 of Set 12 | qarayeri
# Processing Record 15 of Set 12 | necochea
# Processing Record 16 of Set 12 | huadian
# Processing Record 17 of Set 12 | henties bay
# Processing Record 18 of Set 12 | kuusamo
# Processing Record 19 of Set 12 | metehara
# City not found. Skipping...
# Processing Record 20 of Set 12 | derzhavinsk
# Processing Record 21 of Set 12 | saravan
# Processing Record 22 of Set 12 | puerto escondido
# Processing Record 23 of Set 12 | wana
# Processing Record 24 of Set 12 | svetlyy
# Processing Record 25 of Set 12 | sandviken
# Processing Record 26 of Set 12 | debre tabor
# Processing Record 27 of Set 12 | chiredzi
# Processing Record 28 of Set 12 | tolaga bay
# Processing Record 29 of Set 12 | edd
# Processing Record 30 of Set 12 | zubova polyana
# Processing Record 31 of Set 12 | bulungu
# Processing Record 32 of Set 12 | kyaikkami
# Processing Record 33 of Set 12 | port augusta
# Processing Record 34 of Set 12 | hope
# Processing Record 35 of Set 12 | arlit
# Processing Record 36 of Set 12 | leh
# Processing Record 37 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 38 of Set 12 | general roca
# Processing Record 39 of Set 12 | toora-khem
# Processing Record 40 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 41 of Set 12 | tual
# Processing Record 42 of Set 12 | roald
# Processing Record 43 of Set 12 | urengoy
# Processing Record 44 of Set 12 | husavik
# Processing Record 45 of Set 12 | subaytilah
# City not found. Skipping...
# Processing Record 46 of Set 12 | adrar
# Processing Record 47 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 48 of Set 12 | vega de alatorre
# Processing Record 49 of Set 12 | quesnel
# Processing Record 0 of Set 13 | kamina
# Processing Record 1 of Set 13 | northam
# Processing Record 2 of Set 13 | prado
# Processing Record 3 of Set 13 | mananjary
# Processing Record 4 of Set 13 | rosetown
# Processing Record 5 of Set 13 | zhenlai
# Processing Record 6 of Set 13 | tuy hoa
# Processing Record 7 of Set 13 | longlac
# City not found. Skipping...
# Processing Record 8 of Set 13 | iquitos
# Processing Record 9 of Set 13 | ihosy
# Processing Record 10 of Set 13 | ngama
# Processing Record 11 of Set 13 | santiago de cao
# Processing Record 12 of Set 13 | zalantun
# Processing Record 13 of Set 13 | kahului
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Confirm [city_data] list has been populated
list_city_data # output values of [city_data] list
# Out:
# [{'City': 'rikitea',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 292.77,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 4.6,
#   'Country': 'PF',
#   'Date': 1693769122},
#  {'City': 'havre',
#   'Lat': 49.5833,
#   'Lng': 0.3333,
#   'Max Temp': 297.37,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 4.63,
#   'Country': 'FR',
#   'Date': 1693769122},
#  {'City': 'thompson',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': 294.24,
#   'Humidity': 46,
#   'Cloudiness': 100,
#   'Wind Speed': 6.69,
#   'Country': 'CA',
#   'Date': 1693769018},
#  {'City': 'rondonopolis',
#   'Lat': -16.4708,
#   'Lng': -54.6356,
#   'Max Temp': 309.8,
#   'Humidity': 27,
#   'Cloudiness': 100,
#   'Wind Speed': 3.75,
#   'Country': 'BR',
#   'Date': 1693769122},
#  {'City': 'mataura',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 280.64,
#   'Humidity': 98,
#   'Cloudiness': 47,
#   'Wind Speed': 1.34,
#   'Country': 'NZ',
#   'Date': 1693769122},
#  {'City': 'albany',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 303.12,
#   'Humidity': 59,
#   'Cloudiness': 3,
#   'Wind Speed': 0.89,
#   'Country': 'US',
#   'Date': 1693768844},
#  {'City': 'mercedes',
#   'Lat': -34.6515,
#   'Lng': -59.4307,
#   'Max Temp': 282.51,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 6.72,
#   'Country': 'AR',
#   'Date': 1693769096},
#  {'City': 'westport',
#   'Lat': 41.1415,
#   'Lng': -73.3579,
#   'Max Temp': 305.98,
#   'Humidity': 57,
#   'Cloudiness': 0,
#   'Wind Speed': 6.69,
#   'Country': 'US',
#   'Date': 1693769123},
#  {'City': 'limon',
#   'Lat': 10,
#   'Lng': -83.0333,
#   'Max Temp': 303.74,
#   'Humidity': 70,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Country': 'CR',
#   'Date': 1693768964},
#  {'City': 'clyde river',
#   'Lat': 70.4692,
#   'Lng': -68.5914,
#   'Max Temp': 275.28,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 7.2,
#   'Country': 'CA',
#   'Date': 1693769123},
#  {'City': 'hasaki',
#   'Lat': 35.7333,
#   'Lng': 140.8333,
#   'Max Temp': 299.43,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 3.69,
#   'Country': 'JP',
#   'Date': 1693769123},
#  {'City': 'puerto ayora',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 303.13,
#   'Humidity': 90,
#   'Cloudiness': 41,
#   'Wind Speed': 3.58,
#   'Country': 'EC',
#   'Date': 1693768832},
#  {'City': 'aklavik',
#   'Lat': 68.2191,
#   'Lng': -135.0107,
#   'Max Temp': 279.15,
#   'Humidity': 75,
#   'Cloudiness': 75,
#   'Wind Speed': 4.12,
#   'Country': 'CA',
#   'Date': 1693769123},
#  {'City': 'linxia',
#   'Lat': 35.6003,
#   'Lng': 103.2064,
#   'Max Temp': 287.76,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 1.58,
#   'Country': 'CN',
#   'Date': 1693769124},
#  {'City': 'upernavik',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': 275.73,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 1.72,
#   'Country': 'GL',
#   'Date': 1693769124},
#  {'City': 'ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 275.96,
#   'Humidity': 60,
#   'Cloudiness': 75,
#   'Wind Speed': 10.29,
#   'Country': 'AR',
#   'Date': 1693769041},
#  {'City': 'tasiilaq',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 281.24,
#   'Humidity': 89,
#   'Cloudiness': 69,
#   'Wind Speed': 2.14,
#   'Country': 'GL',
#   'Date': 1693769124},
#  {'City': 'souillac',
#   'Lat': -20.5167,
#   'Lng': 57.5167,
#   'Max Temp': 296.36,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 6.69,
#   'Country': 'MU',
#   'Date': 1693769001},
#  {'City': 'esperance',
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp': 282.09,
#   'Humidity': 72,
#   'Cloudiness': 28,
#   'Wind Speed': 8.59,
#   'Country': 'AU',
#   'Date': 1693769124},
#  {'City': 'mar del plata',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 283.16,
#   'Humidity': 85,
#   'Cloudiness': 0,
#   'Wind Speed': 4.12,
#   'Country': 'AR',
#   'Date': 1693769054},
#  {'City': 'kodiak',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 284.88,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 3.09,
#   'Country': 'US',
#   'Date': 1693769125},
#  {'City': 'hilo',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 302.75,
#   'Humidity': 63,
#   'Cloudiness': 40,
#   'Wind Speed': 2.57,
#   'Country': 'US',
#   'Date': 1693769125},
#  {'City': 'sorland',
#   'Lat': 67.667,
#   'Lng': 12.6934,
#   'Max Temp': 285.07,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 9.13,
#   'Country': 'NO',
#   'Date': 1693768935},
#  {'City': 'dwarka',
#   'Lat': 22.2394,
#   'Lng': 68.9678,
#   'Max Temp': 300.57,
#   'Humidity': 75,
#   'Cloudiness': 12,
#   'Wind Speed': 4.18,
#   'Country': 'IN',
#   'Date': 1693769125},
#  {'City': 'orthez',
#   'Lat': 43.4884,
#   'Lng': -0.7724,
#   'Max Temp': 299.23,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 0.92,
#   'Country': 'FR',
#   'Date': 1693769125},
#  {'City': 'busselton',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 286.73,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 9.61,
#   'Country': 'AU',
#   'Date': 1693769126},
#  {'City': 'lavrentiya',
#   'Lat': 65.5833,
#   'Lng': -171,
#   'Max Temp': 278.18,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 6.88,
#   'Country': 'RU',
#   'Date': 1693769126},
#  {'City': 'saint-philippe',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 292.92,
#   'Humidity': 84,
#   'Cloudiness': 46,
#   'Wind Speed': 4.22,
#   'Country': 'RE',
#   'Date': 1693769126},
#  {'City': 'pontal do parana',
#   'Lat': -25.6533,
#   'Lng': -48.5128,
#   'Max Temp': 296.73,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 2.06,
#   'Country': 'BR',
#   'Date': 1693769126},
#  {'City': 'punta arenas',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 277.32,
#   'Humidity': 52,
#   'Cloudiness': 85,
#   'Wind Speed': 6.75,
#   'Country': 'CL',
#   'Date': 1693769126},
#  {'City': 'north myrtle beach',
#   'Lat': 33.816,
#   'Lng': -78.68,
#   'Max Temp': 304.42,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 5.14,
#   'Country': 'US',
#   'Date': 1693768910},
#  {'City': 'faanui',
#   'Lat': -16.4833,
#   'Lng': -151.75,
#   'Max Temp': 298.12,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 7.2,
#   'Country': 'PF',
#   'Date': 1693769127},
#  {'City': 'cape town',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 286.63,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 1.03,
#   'Country': 'ZA',
#   'Date': 1693769127},
#  {'City': 'jieshi',
#   'Lat': 22.8134,
#   'Lng': 115.8257,
#   'Max Temp': 300.74,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 5.09,
#   'Country': 'CN',
#   'Date': 1693769127},
#  {'City': 'mahebourg',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp': 296.31,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 6.69,
#   'Country': 'MU',
#   'Date': 1693769127},
#  {'City': 'saskylakh',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': 272.61,
#   'Humidity': 96,
#   'Cloudiness': 99,
#   'Wind Speed': 3.64,
#   'Country': 'RU',
#   'Date': 1693769127},
#  {'City': 'cayenne',
#   'Lat': 4.9333,
#   'Lng': -52.3333,
#   'Max Temp': 305.17,
#   'Humidity': 62,
#   'Cloudiness': 75,
#   'Wind Speed': 6.69,
#   'Country': 'GF',
#   'Date': 1693769128},
#  {'City': 'arraial do cabo',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 298.13,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 9.77,
#   'Country': 'BR',
#   'Date': 1693769128},
#  {'City': 'moroni',
#   'Lat': -11.7022,
#   'Lng': 43.2551,
#   'Max Temp': 297.7,
#   'Humidity': 79,
#   'Cloudiness': 1,
#   'Wind Speed': 0.85,
#   'Country': 'KM',
#   'Date': 1693769099},
#  {'City': 'jamestown',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 303.72,
#   'Humidity': 48,
#   'Cloudiness': 0,
#   'Wind Speed': 5.66,
#   'Country': 'US',
#   'Date': 1693769065},
#  {'City': 'haverfordwest',
#   'Lat': 51.8017,
#   'Lng': -4.9691,
#   'Max Temp': 292.92,
#   'Humidity': 87,
#   'Cloudiness': 0,
#   'Wind Speed': 2.24,
#   'Country': 'GB',
#   'Date': 1693769128},
#  {'City': 'lodja',
#   'Lat': -3.4833,
#   'Lng': 23.4333,
#   'Max Temp': 294.83,
#   'Humidity': 95,
#   'Cloudiness': 39,
#   'Wind Speed': 1.38,
#   'Country': 'CD',
#   'Date': 1693769128},
#  {'City': 'marshall',
#   'Lat': 34.3834,
#   'Lng': -86.3333,
#   'Max Temp': 306.1,
#   'Humidity': 53,
#   'Cloudiness': 0,
#   'Wind Speed': 2.57,
#   'Country': 'US',
#   'Date': 1693769129},
#  {'City': 'kangaatsiaq',
#   'Lat': 68.3065,
#   'Lng': -53.4641,
#   'Max Temp': 276.39,
#   'Humidity': 69,
#   'Cloudiness': 94,
#   'Wind Speed': 0.78,
#   'Country': 'GL',
#   'Date': 1693769129},
#  {'City': 'moron',
#   'Lat': -34.6534,
#   'Lng': -58.6198,
#   'Max Temp': 284.24,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 3.99,
#   'Country': 'AR',
#   'Date': 1693769129},
#  {'City': 'kapaa',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 301.33,
#   'Humidity': 77,
#   'Cloudiness': 40,
#   'Wind Speed': 7.72,
#   'Country': 'US',
#   'Date': 1693768944},
#  {'City': 'torbay',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp': 295.31,
#   'Humidity': 68,
#   'Cloudiness': 40,
#   'Wind Speed': 9.77,
#   'Country': 'CA',
#   'Date': 1693769130},
#  {'City': 'east london',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 291,
#   'Humidity': 82,
#   'Cloudiness': 19,
#   'Wind Speed': 2.38,
#   'Country': 'ZA',
#   'Date': 1693769130},
#  {'City': 'sassari',
#   'Lat': 40.7272,
#   'Lng': 8.5603,
#   'Max Temp': 298.03,
#   'Humidity': 55,
#   'Cloudiness': 2,
#   'Wind Speed': 1.87,
#   'Country': 'IT',
#   'Date': 1693769131},
#  {'City': 'surt',
#   'Lat': 31.2089,
#   'Lng': 16.5887,
#   'Max Temp': 299.9,
#   'Humidity': 66,
#   'Cloudiness': 99,
#   'Wind Speed': 5.02,
#   'Country': 'LY',
#   'Date': 1693769131},
#  {'City': 'atuona',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 299.29,
#   'Humidity': 78,
#   'Cloudiness': 7,
#   'Wind Speed': 9.24,
#   'Country': 'PF',
#   'Date': 1693769131},
#  {'City': 'castro',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 298.79,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 3.14,
#   'Country': 'BR',
#   'Date': 1693769131},
#  {'City': 'sisimiut',
#   'Lat': 66.9395,
#   'Lng': -53.6735,
#   'Max Temp': 277.51,
#   'Humidity': 60,
#   'Cloudiness': 92,
#   'Wind Speed': 2.48,
#   'Country': 'GL',
#   'Date': 1693769131},
#  {'City': 'tiksi',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': 272.8,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 1.9,
#   'Country': 'RU',
#   'Date': 1693769132},
#  {'City': 'bluff',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 280.82,
#   'Humidity': 89,
#   'Cloudiness': 44,
#   'Wind Speed': 2.91,
#   'Country': 'NZ',
#   'Date': 1693769132},
#  {'City': 'honiara',
#   'Lat': -9.4333,
#   'Lng': 159.95,
#   'Max Temp': 298.02,
#   'Humidity': 85,
#   'Cloudiness': 82,
#   'Wind Speed': 2.55,
#   'Country': 'SB',
#   'Date': 1693768895},
#  {'City': 'igarka',
#   'Lat': 67.4667,
#   'Lng': 86.5833,
#   'Max Temp': 277.06,
#   'Humidity': 74,
#   'Cloudiness': 21,
#   'Wind Speed': 6.04,
#   'Country': 'RU',
#   'Date': 1693769132},
#  {'City': 'hobart',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 278.74,
#   'Humidity': 84,
#   'Cloudiness': 1,
#   'Wind Speed': 0.89,
#   'Country': 'AU',
#   'Date': 1693769132},
#  {'City': 'cabo san lucas',
#   'Lat': 22.8909,
#   'Lng': -109.9124,
#   'Max Temp': 309.76,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 2.06,
#   'Country': 'MX',
#   'Date': 1693769133},
#  {'City': 'padang',
#   'Lat': -0.9492,
#   'Lng': 100.3543,
#   'Max Temp': 299.18,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 3.22,
#   'Country': 'ID',
#   'Date': 1693769133},
#  {'City': 'hermanus',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 286.93,
#   'Humidity': 81,
#   'Cloudiness': 5,
#   'Wind Speed': 5.84,
#   'Country': 'ZA',
#   'Date': 1693769133},
#  {'City': 'tuktoyaktuk',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': 275.15,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 1.54,
#   'Country': 'CA',
#   'Date': 1693769133},
#  {'City': 'quelimane',
#   'Lat': -17.8786,
#   'Lng': 36.8883,
#   'Max Temp': 297.12,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 5.14,
#   'Country': 'MZ',
#   'Date': 1693769133},
#  {'City': 'yerofey pavlovich',
#   'Lat': 53.9667,
#   'Lng': 121.9667,
#   'Max Temp': 279.39,
#   'Humidity': 56,
#   'Cloudiness': 100,
#   'Wind Speed': 0.77,
#   'Country': 'RU',
#   'Date': 1693769134},
#  {'City': 'constitucion',
#   'Lat': -35.3333,
#   'Lng': -72.4167,
#   'Max Temp': 285.23,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 1.61,
#   'Country': 'CL',
#   'Date': 1693769134},
#  {'City': 'port alfred',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 290.13,
#   'Humidity': 85,
#   'Cloudiness': 40,
#   'Wind Speed': 2.5,
#   'Country': 'ZA',
#   'Date': 1693769134},
#  {'City': 'turukhansk',
#   'Lat': 65.8167,
#   'Lng': 87.9833,
#   'Max Temp': 283.69,
#   'Humidity': 81,
#   'Cloudiness': 99,
#   'Wind Speed': 3.59,
#   'Country': 'RU',
#   'Date': 1693769134},
#  {'City': 'lagoa',
#   'Lat': 39.05,
#   'Lng': -27.9833,
#   'Max Temp': 295.98,
#   'Humidity': 78,
#   'Cloudiness': 15,
#   'Wind Speed': 3.71,
#   'Country': 'PT',
#   'Date': 1693769134},
#  {'City': 'zhangye',
#   'Lat': 38.9342,
#   'Lng': 100.4517,
#   'Max Temp': 294.68,
#   'Humidity': 31,
#   'Cloudiness': 22,
#   'Wind Speed': 3.66,
#   'Country': 'CN',
#   'Date': 1693769135},
#  {'City': 'barrow',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': 277.16,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 6.17,
#   'Country': 'US',
#   'Date': 1693769135},
#  {'City': 'vardo',
#   'Lat': 70.3705,
#   'Lng': 31.1107,
#   'Max Temp': 286.14,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 1.03,
#   'Country': 'NO',
#   'Date': 1693769135},
#  {'City': 'nome',
#   'Lat': 64.5011,
#   'Lng': -165.4064,
#   'Max Temp': 282.68,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 5.66,
#   'Country': 'US',
#   'Date': 1693769135},
#  {'City': 'cherdyn',
#   'Lat': 60.403,
#   'Lng': 56.4787,
#   'Max Temp': 285.92,
#   'Humidity': 61,
#   'Cloudiness': 100,
#   'Wind Speed': 1.22,
#   'Country': 'RU',
#   'Date': 1693769135},
#  {'City': 'bonavista',
#   'Lat': 48.6499,
#   'Lng': -53.1147,
#   'Max Temp': 291.94,
#   'Humidity': 67,
#   'Cloudiness': 6,
#   'Wind Speed': 7.58,
#   'Country': 'CA',
#   'Date': 1693769135},
#  {'City': 'rancho palos verdes',
#   'Lat': 33.7445,
#   'Lng': -118.387,
#   'Max Temp': 299.77,
#   'Humidity': 68,
#   'Cloudiness': 75,
#   'Wind Speed': 6.69,
#   'Country': 'US',
#   'Date': 1693769093},
#  {'City': 'ribas do rio pardo',
#   'Lat': -20.4431,
#   'Lng': -53.7592,
#   'Max Temp': 311.11,
#   'Humidity': 22,
#   'Cloudiness': 66,
#   'Wind Speed': 6.96,
#   'Country': 'BR',
#   'Date': 1693769136},
#  {'City': 'am timan',
#   'Lat': 11.0297,
#   'Lng': 20.2827,
#   'Max Temp': 297.71,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 1.75,
#   'Country': 'TD',
#   'Date': 1693769136},
#  {'City': 'douglas',
#   'Lat': 41.3,
#   'Lng': -96.167,
#   'Max Temp': 308.25,
#   'Humidity': 29,
#   'Cloudiness': 0,
#   'Wind Speed': 7.72,
#   'Country': 'US',
#   'Date': 1693769136},
#  {'City': 'svetlaya',
#   'Lat': 46.5389,
#   'Lng': 138.3297,
#   'Max Temp': 289.34,
#   'Humidity': 90,
#   'Cloudiness': 93,
#   'Wind Speed': 5.97,
#   'Country': 'RU',
#   'Date': 1693769136},
#  {'City': 'beringovskiy',
#   'Lat': 63.05,
#   'Lng': 179.3167,
#   'Max Temp': 280.44,
#   'Humidity': 63,
#   'Cloudiness': 95,
#   'Wind Speed': 2.85,
#   'Country': 'RU',
#   'Date': 1693769136},
#  {'City': 'oranjestad',
#   'Lat': 12.524,
#   'Lng': -70.027,
#   'Max Temp': 304.12,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 6.69,
#   'Country': 'AW',
#   'Date': 1693769136},
#  {'City': 'carnarvon',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 291.02,
#   'Humidity': 59,
#   'Cloudiness': 100,
#   'Wind Speed': 7.35,
#   'Country': 'AU',
#   'Date': 1693769137},
#  {'City': 'kizhinga',
#   'Lat': 51.8462,
#   'Lng': 109.9097,
#   'Max Temp': 278.69,
#   'Humidity': 94,
#   'Cloudiness': 8,
#   'Wind Speed': 0.88,
#   'Country': 'RU',
#   'Date': 1693769137},
#  {'City': 'bredasdorp',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 282.15,
#   'Humidity': 85,
#   'Cloudiness': 5,
#   'Wind Speed': 3.28,
#   'Country': 'ZA',
#   'Date': 1693769137},
#  {'City': 'kalilangan',
#   'Lat': 7.8211,
#   'Lng': 124.7314,
#   'Max Temp': 292.53,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 0.34,
#   'Country': 'PH',
#   'Date': 1693769137},
#  {'City': 'buenos aires',
#   'Lat': -34.6132,
#   'Lng': -58.3772,
#   'Max Temp': 284.23,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 9.39,
#   'Country': 'AR',
#   'Date': 1693768736},
#  {'City': 'madang',
#   'Lat': -5.2246,
#   'Lng': 145.7966,
#   'Max Temp': 297.13,
#   'Humidity': 91,
#   'Cloudiness': 98,
#   'Wind Speed': 0.32,
#   'Country': 'PG',
#   'Date': 1693769138},
#  {'City': 'sovetskiy',
#   'Lat': 61.3614,
#   'Lng': 63.5842,
#   'Max Temp': 284.76,
#   'Humidity': 69,
#   'Cloudiness': 72,
#   'Wind Speed': 1.34,
#   'Country': 'RU',
#   'Date': 1693769138},
#  {'City': 'victoria',
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp': 302.77,
#   'Humidity': 83,
#   'Cloudiness': 96,
#   'Wind Speed': 4.13,
#   'Country': 'HK',
#   'Date': 1693769103},
#  {'City': 'chuy',
#   'Lat': -33.6971,
#   'Lng': -53.4616,
#   'Max Temp': 287.92,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 2.37,
#   'Country': 'UY',
#   'Date': 1693769138},
#  {'City': 'kudahuvadhoo',
#   'Lat': 2.6708,
#   'Lng': 72.8944,
#   'Max Temp': 300.85,
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 3.91,
#   'Country': 'MV',
#   'Date': 1693769138},
#  {'City': 'mildura',
#   'Lat': -34.2,
#   'Lng': 142.15,
#   'Max Temp': 288.19,
#   'Humidity': 45,
#   'Cloudiness': 100,
#   'Wind Speed': 7.46,
#   'Country': 'AU',
#   'Date': 1693769138},
#  {'City': 'honningsvag',
#   'Lat': 70.9821,
#   'Lng': 25.9704,
#   'Max Temp': 287.01,
#   'Humidity': 82,
#   'Cloudiness': 27,
#   'Wind Speed': 5.14,
#   'Country': 'NO',
#   'Date': 1693769138},
#  {'City': 'vokhtoga',
#   'Lat': 58.8147,
#   'Lng': 41.0461,
#   'Max Temp': 287.18,
#   'Humidity': 85,
#   'Cloudiness': 94,
#   'Wind Speed': 0.73,
#   'Country': 'RU',
#   'Date': 1693769140},
#  {'City': 'samarai',
#   'Lat': -10.6167,
#   'Lng': 150.6667,
#   'Max Temp': 297.31,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 3.72,
#   'Country': 'PG',
#   'Date': 1693769140},
#  {'City': 'sivas',
#   'Lat': 39.7916,
#   'Lng': 37.0019,
#   'Max Temp': 288.5,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 1.03,
#   'Country': 'TR',
#   'Date': 1693769140},
#  {'City': 'garoua',
#   'Lat': 9.3,
#   'Lng': 13.4,
#   'Max Temp': 299.18,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 0.43,
#   'Country': 'CM',
#   'Date': 1693769140},
#  {'City': 'ilulissat',
#   'Lat': 69.2167,
#   'Lng': -51.1,
#   'Max Temp': 277.16,
#   'Humidity': 75,
#   'Cloudiness': 75,
#   'Wind Speed': 4.63,
#   'Country': 'GL',
#   'Date': 1693769140},
#  {'City': 'manikganj',
#   'Lat': 23.8553,
#   'Lng': 90.0125,
#   'Max Temp': 302.14,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 2.56,
#   'Country': 'BD',
#   'Date': 1693769140},
#  {'City': 'luderitz',
#   'Lat': -26.6481,
#   'Lng': 15.1594,
#   'Max Temp': 286.24,
#   'Humidity': 70,
#   'Cloudiness': 0,
#   'Wind Speed': 7.08,
#   'Country': 'NA',
#   'Date': 1693769141},
#  {'City': 'severo-kurilsk',
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Max Temp': 284.91,
#   'Humidity': 96,
#   'Cloudiness': 58,
#   'Wind Speed': 5.19,
#   'Country': 'RU',
#   'Date': 1693769141},
#  {'City': 'sitka',
#   'Lat': 57.0531,
#   'Lng': -135.33,
#   'Max Temp': 286.09,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 1.54,
#   'Country': 'US',
#   'Date': 1693769141},
#  {'City': 'katsuura',
#   'Lat': 35.1333,
#   'Lng': 140.3,
#   'Max Temp': 298.74,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 3.51,
#   'Country': 'JP',
#   'Date': 1693769141},
#  {'City': 'talnakh',
#   'Lat': 69.4865,
#   'Lng': 88.3972,
#   'Max Temp': 276.6,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 4.94,
#   'Country': 'RU',
#   'Date': 1693769141},
#  {'City': 'bengkulu',
#   'Lat': -3.8004,
#   'Lng': 102.2655,
#   'Max Temp': 295.44,
#   'Humidity': 87,
#   'Cloudiness': 15,
#   'Wind Speed': 3.62,
#   'Country': 'ID',
#   'Date': 1693769142},
#  {'City': 'anadyr',
#   'Lat': 64.75,
#   'Lng': 177.4833,
#   'Max Temp': 276.43,
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 4.92,
#   'Country': 'RU',
#   'Date': 1693769142},
#  {'City': 'port keats',
#   'Lat': -14.25,
#   'Lng': 129.55,
#   'Max Temp': 295.25,
#   'Humidity': 83,
#   'Cloudiness': 6,
#   'Wind Speed': 1.62,
#   'Country': 'AU',
#   'Date': 1693769142},
#  {'City': 'weihe',
#   'Lat': 32.9952,
#   'Lng': 105.3247,
#   'Max Temp': 289.81,
#   'Humidity': 93,
#   'Cloudiness': 5,
#   'Wind Speed': 0.98,
#   'Country': 'CN',
#   'Date': 1693769142},
#  {'City': 'sola',
#   'Lat': -13.8833,
#   'Lng': 167.55,
#   'Max Temp': 298.91,
#   'Humidity': 85,
#   'Cloudiness': 99,
#   'Wind Speed': 8.46,
#   'Country': 'VU',
#   'Date': 1693769142},
#  {'City': 'cidreira',
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp': 291.84,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 0.8,
#   'Country': 'BR',
#   'Date': 1693769143},
#  {'City': 'los angeles',
#   'Lat': 34.0522,
#   'Lng': -118.2437,
#   'Max Temp': 299.82,
#   'Humidity': 59,
#   'Cloudiness': 75,
#   'Wind Speed': 6.17,
#   'Country': 'US',
#   'Date': 1693769141},
#  {'City': 'georgetown',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 302.12,
#   'Humidity': 81,
#   'Cloudiness': 20,
#   'Wind Speed': 2.57,
#   'Country': 'MY',
#   'Date': 1693769013},
#  {'City': 'porto velho',
#   'Lat': -8.7619,
#   'Lng': -63.9039,
#   'Max Temp': 308.18,
#   'Humidity': 38,
#   'Cloudiness': 40,
#   'Wind Speed': 2.57,
#   'Country': 'BR',
#   'Date': 1693768963},
#  {'City': 'yellowknife',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': 286.16,
#   'Humidity': 73,
#   'Cloudiness': 75,
#   'Wind Speed': 6.17,
#   'Country': 'CA',
#   'Date': 1693769143},
#  {'City': 'buala',
#   'Lat': -8.145,
#   'Lng': 159.5921,
#   'Max Temp': 299.57,
#   'Humidity': 84,
#   'Cloudiness': 39,
#   'Wind Speed': 2.91,
#   'Country': 'SB',
#   'Date': 1693769143},
#  {'City': 'taltal',
#   'Lat': -25.4,
#   'Lng': -70.4833,
#   'Max Temp': 288.01,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 0.59,
#   'Country': 'CL',
#   'Date': 1693769143},
#  {'City': 'lebu',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 283.2,
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 6.23,
#   'Country': 'CL',
#   'Date': 1693769144},
#  {'City': 'malabo',
#   'Lat': 3.75,
#   'Lng': 8.7833,
#   'Max Temp': 298.81,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 3.94,
#   'Country': 'GQ',
#   'Date': 1693769144},
#  {'City': 'antalaha',
#   'Lat': -14.9003,
#   'Lng': 50.2788,
#   'Max Temp': 294.23,
#   'Humidity': 81,
#   'Cloudiness': 73,
#   'Wind Speed': 3.04,
#   'Country': 'MG',
#   'Date': 1693769144},
#  {'City': 'chas',
#   'Lat': 23.6333,
#   'Lng': 86.1667,
#   'Max Temp': 300.55,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 1.74,
#   'Country': 'IN',
#   'Date': 1693769144},
#  {'City': 'havelock',
#   'Lat': 34.8791,
#   'Lng': -76.9013,
#   'Max Temp': 304.12,
#   'Humidity': 57,
#   'Cloudiness': 0,
#   'Wind Speed': 2.06,
#   'Country': 'US',
#   'Date': 1693769144},
#  {'City': 'comodoro rivadavia',
#   'Lat': -45.8667,
#   'Lng': -67.5,
#   'Max Temp': 280.07,
#   'Humidity': 61,
#   'Cloudiness': 40,
#   'Wind Speed': 3.6,
#   'Country': 'AR',
#   'Date': 1693769144},
#  {'City': 'didsbury',
#   'Lat': 53.417,
#   'Lng': -2.2315,
#   'Max Temp': 293.88,
#   'Humidity': 78,
#   'Cloudiness': 44,
#   'Wind Speed': 1.54,
#   'Country': 'GB',
#   'Date': 1693769145},
#  {'City': 'deputatskiy',
#   'Lat': 69.3,
#   'Lng': 139.9,
#   'Max Temp': 272.28,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 1.63,
#   'Country': 'RU',
#   'Date': 1693769145},
#  {'City': 'bambous virieux',
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Max Temp': 296.29,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 6.69,
#   'Country': 'MU',
#   'Date': 1693769145},
#  {'City': 'fortuna',
#   'Lat': 40.5982,
#   'Lng': -124.1573,
#   'Max Temp': 295.33,
#   'Humidity': 73,
#   'Cloudiness': 40,
#   'Wind Speed': 6.17,
#   'Country': 'US',
#   'Date': 1693769145},
#  {'City': 'mehamn',
#   'Lat': 71.0357,
#   'Lng': 27.8492,
#   'Max Temp': 289.1,
#   'Humidity': 82,
#   'Cloudiness': 20,
#   'Wind Speed': 5.66,
#   'Country': 'NO',
#   'Date': 1693769145},
#  {'City': 'teahupoo',
#   'Lat': -17.8333,
#   'Lng': -149.2667,
#   'Max Temp': 295.13,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 8.94,
#   'Country': 'PF',
#   'Date': 1693769145},
#  {'City': 'dingle',
#   'Lat': 10.9995,
#   'Lng': 122.6711,
#   'Max Temp': 298.42,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 3.91,
#   'Country': 'PH',
#   'Date': 1693769146},
#  {'City': 'kavaratti',
#   'Lat': 10.5669,
#   'Lng': 72.642,
#   'Max Temp': 300.36,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 7.9,
#   'Country': 'IN',
#   'Date': 1693769146},
#  {'City': 'sao lourenco do sul',
#   'Lat': -31.3653,
#   'Lng': -51.9783,
#   'Max Temp': 291.83,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 4.42,
#   'Country': 'BR',
#   'Date': 1693769146},
#  {'City': 'weligama',
#   'Lat': 5.9667,
#   'Lng': 80.4167,
#   'Max Temp': 298.11,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 7.18,
#   'Country': 'LK',
#   'Date': 1693768510},
#  {'City': 'wajir',
#   'Lat': 1.7471,
#   'Lng': 40.0573,
#   'Max Temp': 302.86,
#   'Humidity': 39,
#   'Cloudiness': 100,
#   'Wind Speed': 11.28,
#   'Country': 'KE',
#   'Date': 1693769146},
#  {'City': 'dikson',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': 276.76,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 1.34,
#   'Country': 'RU',
#   'Date': 1693769146},
#  {'City': 'suifenhe',
#   'Lat': 44.4,
#   'Lng': 131.1667,
#   'Max Temp': 287.05,
#   'Humidity': 95,
#   'Cloudiness': 0,
#   'Wind Speed': 1.01,
#   'Country': 'CN',
#   'Date': 1693769147},
#  {'City': 'atar',
#   'Lat': 20.5169,
#   'Lng': -13.0499,
#   'Max Temp': 311.81,
#   'Humidity': 18,
#   'Cloudiness': 5,
#   'Wind Speed': 5.48,
#   'Country': 'MR',
#   'Date': 1693769147},
#  {'City': 'garmsar',
#   'Lat': 35.2182,
#   'Lng': 52.3409,
#   'Max Temp': 304.78,
#   'Humidity': 17,
#   'Cloudiness': 5,
#   'Wind Speed': 4.25,
#   'Country': 'IR',
#   'Date': 1693769147},
#  {'City': 'vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 294.24,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 0.51,
#   'Country': 'TO',
#   'Date': 1693769147},
#  {'City': 'kaitangata',
#   'Lat': -46.2817,
#   'Lng': 169.8464,
#   'Max Temp': 279.26,
#   'Humidity': 95,
#   'Cloudiness': 24,
#   'Wind Speed': 2.7,
#   'Country': 'NZ',
#   'Date': 1693769147},
#  {'City': 'tiznit',
#   'Lat': 29.5833,
#   'Lng': -9.5,
#   'Max Temp': 291.51,
#   'Humidity': 67,
#   'Cloudiness': 13,
#   'Wind Speed': 4.31,
#   'Country': 'MA',
#   'Date': 1693769147},
#  {'City': 'kawalu',
#   'Lat': -7.3817,
#   'Lng': 108.2082,
#   'Max Temp': 291.54,
#   'Humidity': 91,
#   'Cloudiness': 52,
#   'Wind Speed': 0.16,
#   'Country': 'ID',
#   'Date': 1693769148},
#  {'City': 'qaanaaq',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': 272.18,
#   'Humidity': 66,
#   'Cloudiness': 90,
#   'Wind Speed': 3.35,
#   'Country': 'GL',
#   'Date': 1693769149},
#  {'City': 'kieta',
#   'Lat': -6.2167,
#   'Lng': 155.6333,
#   'Max Temp': 298.47,
#   'Humidity': 85,
#   'Cloudiness': 44,
#   'Wind Speed': 2.64,
#   'Country': 'PG',
#   'Date': 1693769149},
#  {'City': 'nikolskoye',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 288.6,
#   'Humidity': 90,
#   'Cloudiness': 52,
#   'Wind Speed': 1.4,
#   'Country': 'RU',
#   'Date': 1693769149},
#  {'City': 'bay roberts',
#   'Lat': 47.5999,
#   'Lng': -53.2648,
#   'Max Temp': 295.74,
#   'Humidity': 67,
#   'Cloudiness': 66,
#   'Wind Speed': 4.02,
#   'Country': 'CA',
#   'Date': 1693769149},
#  {'City': 'kashi',
#   'Lat': 39.4547,
#   'Lng': 75.9797,
#   'Max Temp': 298.71,
#   'Humidity': 27,
#   'Cloudiness': 20,
#   'Wind Speed': 5,
#   'Country': 'CN',
#   'Date': 1693769149},
#  {'City': 'ribeira grande',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 298.37,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 4.12,
#   'Country': 'PT',
#   'Date': 1693769150},
#  {'City': 'butaritari',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 301.37,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 5.34,
#   'Country': 'KI',
#   'Date': 1693769150},
#  {'City': 'caravelas',
#   'Lat': -17.7125,
#   'Lng': -39.2481,
#   'Max Temp': 297.93,
#   'Humidity': 63,
#   'Cloudiness': 100,
#   'Wind Speed': 3.62,
#   'Country': 'BR',
#   'Date': 1693769150},
#  {'City': 'amuntai',
#   'Lat': -2.4177,
#   'Lng': 115.2494,
#   'Max Temp': 295.12,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 0.57,
#   'Country': 'ID',
#   'Date': 1693769150},
#  {'City': 'norman wells',
#   'Lat': 65.282,
#   'Lng': -126.8329,
#   'Max Temp': 279.17,
#   'Humidity': 65,
#   'Cloudiness': 75,
#   'Wind Speed': 8.23,
#   'Country': 'CA',
#   'Date': 1693769150},
#  {'City': 'ponta do sol',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 298.15,
#   'Humidity': 64,
#   'Cloudiness': 9,
#   'Wind Speed': 2.61,
#   'Country': 'PT',
#   'Date': 1693769150},
#  {'City': 'tomohon',
#   'Lat': 1.3346,
#   'Lng': 124.8392,
#   'Max Temp': 290.67,
#   'Humidity': 89,
#   'Cloudiness': 80,
#   'Wind Speed': 1.95,
#   'Country': 'ID',
#   'Date': 1693769151},
#  {'City': 'costa rica',
#   'Lat': -23.4167,
#   'Lng': -54.65,
#   'Max Temp': 308.83,
#   'Humidity': 30,
#   'Cloudiness': 65,
#   'Wind Speed': 6.62,
#   'Country': 'BR',
#   'Date': 1693769031},
#  {'City': 'areosa',
#   'Lat': 41.7178,
#   'Lng': -8.8571,
#   'Max Temp': 291.43,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 0.97,
#   'Country': 'PT',
#   'Date': 1693769151},
#  {'City': 'makakilo city',
#   'Lat': 21.3469,
#   'Lng': -158.0858,
#   'Max Temp': 300.38,
#   'Humidity': 70,
#   'Cloudiness': 20,
#   'Wind Speed': 4.63,
#   'Country': 'US',
#   'Date': 1693769151},
#  {'City': 'katy',
#   'Lat': 29.7858,
#   'Lng': -95.8244,
#   'Max Temp': 311.54,
#   'Humidity': 44,
#   'Cloudiness': 20,
#   'Wind Speed': 3.09,
#   'Country': 'US',
#   'Date': 1693769072},
#  {'City': 'namibe',
#   'Lat': -15.1961,
#   'Lng': 12.1522,
#   'Max Temp': 291.68,
#   'Humidity': 85,
#   'Cloudiness': 99,
#   'Wind Speed': 3.37,
#   'Country': 'AO',
#   'Date': 1693769151},
#  {'City': 'krasnoselkup',
#   'Lat': 65.7,
#   'Lng': 82.4667,
#   'Max Temp': 279.1,
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 7.9,
#   'Country': 'RU',
#   'Date': 1693769152},
#  {'City': 'kizner',
#   'Lat': 56.2749,
#   'Lng': 51.508,
#   'Max Temp': 286.44,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 1.13,
#   'Country': 'RU',
#   'Date': 1693769152},
#  {'City': 'eldorado',
#   'Lat': -23.7869,
#   'Lng': -54.2836,
#   'Max Temp': 307.76,
#   'Humidity': 34,
#   'Cloudiness': 100,
#   'Wind Speed': 4.68,
#   'Country': 'BR',
#   'Date': 1693769152},
#  {'City': 'pimentel',
#   'Lat': -6.8367,
#   'Lng': -79.9342,
#   'Max Temp': 298.31,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 5.66,
#   'Country': 'PE',
#   'Date': 1693769152},
#  {'City': 'port elizabeth',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 288.31,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 2.06,
#   'Country': 'ZA',
#   'Date': 1693769152},
#  {'City': 'coihaique',
#   'Lat': -45.5752,
#   'Lng': -72.0662,
#   'Max Temp': 281.12,
#   'Humidity': 42,
#   'Cloudiness': 40,
#   'Wind Speed': 2.57,
#   'Country': 'CL',
#   'Date': 1693769152},
#  {'City': 'lata',
#   'Lat': 40.1629,
#   'Lng': -8.3327,
#   'Max Temp': 294.77,
#   'Humidity': 64,
#   'Cloudiness': 83,
#   'Wind Speed': 1.62,
#   'Country': 'PT',
#   'Date': 1693769152},
#  {'City': 'olafsvik',
#   'Lat': 64.8945,
#   'Lng': -23.7142,
#   'Max Temp': 281.85,
#   'Humidity': 64,
#   'Cloudiness': 53,
#   'Wind Speed': 11.48,
#   'Country': 'IS',
#   'Date': 1693769153},
#  {'City': 'marfino',
#   'Lat': 55.7028,
#   'Lng': 37.3822,
#   'Max Temp': 289.72,
#   'Humidity': 93,
#   'Cloudiness': 0,
#   'Wind Speed': 1,
#   'Country': 'RU',
#   'Date': 1693769153},
#  {'City': 'hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 301.14,
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 1.58,
#   'Country': 'MV',
#   'Date': 1693769153},
#  {'City': 'oranjemund',
#   'Lat': -28.55,
#   'Lng': 16.4333,
#   'Max Temp': 285.41,
#   'Humidity': 83,
#   'Cloudiness': 3,
#   'Wind Speed': 3.45,
#   'Country': 'NA',
#   'Date': 1693769153},
#  {'City': 'asosa',
#   'Lat': 10.0667,
#   'Lng': 34.5333,
#   'Max Temp': 289.75,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 1.73,
#   'Country': 'ET',
#   'Date': 1693769153},
#  {'City': 'marawi',
#   'Lat': 7.9986,
#   'Lng': 124.2928,
#   'Max Temp': 294.17,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 2.43,
#   'Country': 'PH',
#   'Date': 1693769153},
#  {'City': 'saint george',
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Max Temp': 302.83,
#   'Humidity': 43,
#   'Cloudiness': 0,
#   'Wind Speed': 2.06,
#   'Country': 'US',
#   'Date': 1693769154},
#  {'City': 'hami',
#   'Lat': 42.8,
#   'Lng': 93.45,
#   'Max Temp': 300.08,
#   'Humidity': 19,
#   'Cloudiness': 87,
#   'Wind Speed': 1.25,
#   'Country': 'CN',
#   'Date': 1693769154},
#  {'City': 'bariadi',
#   'Lat': -2.8,
#   'Lng': 33.9833,
#   'Max Temp': 299.45,
#   'Humidity': 41,
#   'Cloudiness': 95,
#   'Wind Speed': 2.28,
#   'Country': 'TZ',
#   'Date': 1693769154},
#  {'City': 'hassleholm',
#   'Lat': 56.1591,
#   'Lng': 13.7664,
#   'Max Temp': 288.9,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 2.34,
#   'Country': 'SE',
#   'Date': 1693769154},
#  {'City': 'alyangula',
#   'Lat': -13.8483,
#   'Lng': 136.4192,
#   'Max Temp': 295.56,
#   'Humidity': 72,
#   'Cloudiness': 6,
#   'Wind Speed': 2.43,
#   'Country': 'AU',
#   'Date': 1693769154},
#  {'City': 'collie',
#   'Lat': -33.3667,
#   'Lng': 116.15,
#   'Max Temp': 284.86,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 6.17,
#   'Country': 'AU',
#   'Date': 1693769155},
#  {'City': 'nioro',
#   'Lat': 13.35,
#   'Lng': -15.75,
#   'Max Temp': 301.51,
#   'Humidity': 83,
#   'Cloudiness': 90,
#   'Wind Speed': 0.91,
#   'Country': 'GM',
#   'Date': 1693769157},
#  {'City': 'pangani',
#   'Lat': -5.4333,
#   'Lng': 38.9667,
#   'Max Temp': 296.6,
#   'Humidity': 82,
#   'Cloudiness': 1,
#   'Wind Speed': 4.17,
#   'Country': 'TZ',
#   'Date': 1693769157},
#  {'City': 'bambanglipuro',
#   'Lat': -7.95,
#   'Lng': 110.2833,
#   'Max Temp': 293.97,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 1.34,
#   'Country': 'ID',
#   'Date': 1693769157},
#  {'City': 'acari',
#   'Lat': -15.4311,
#   'Lng': -74.6158,
#   'Max Temp': 297.03,
#   'Humidity': 57,
#   'Cloudiness': 0,
#   'Wind Speed': 6.2,
#   'Country': 'PE',
#   'Date': 1693769157},
#  {'City': 'tuatapere',
#   'Lat': -46.1333,
#   'Lng': 167.6833,
#   'Max Temp': 280.26,
#   'Humidity': 95,
#   'Cloudiness': 97,
#   'Wind Speed': 1.75,
#   'Country': 'NZ',
#   'Date': 1693769157},
#  {'City': 'sur',
#   'Lat': 22.5667,
#   'Lng': 59.5289,
#   'Max Temp': 300.77,
#   'Humidity': 72,
#   'Cloudiness': 3,
#   'Wind Speed': 7.41,
#   'Country': 'OM',
#   'Date': 1693769157},
#  {'City': 'hovd',
#   'Lat': 48.0056,
#   'Lng': 91.6419,
#   'Max Temp': 290.17,
#   'Humidity': 27,
#   'Cloudiness': 9,
#   'Wind Speed': 2.4,
#   'Country': 'MN',
#   'Date': 1693769158},
#  {'City': 'longyan',
#   'Lat': 25.1072,
#   'Lng': 117.0225,
#   'Max Temp': 297.44,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 2.77,
#   'Country': 'CN',
#   'Date': 1693769158},
#  {'City': 'chimoio',
#   'Lat': -19.1164,
#   'Lng': 33.4833,
#   'Max Temp': 293.07,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 3.29,
#   'Country': 'MZ',
#   'Date': 1693769158},
#  {'City': 'yakeshi',
#   'Lat': 49.2833,
#   'Lng': 120.7333,
#   'Max Temp': 280.73,
#   'Humidity': 88,
#   'Cloudiness': 97,
#   'Wind Speed': 1.72,
#   'Country': 'CN',
#   'Date': 1693769158},
#  {'City': 'verkhnevilyuysk',
#   'Lat': 63.4453,
#   'Lng': 120.3167,
#   'Max Temp': 275.75,
#   'Humidity': 76,
#   'Cloudiness': 58,
#   'Wind Speed': 0.98,
#   'Country': 'RU',
#   'Date': 1693769158},
#  {'City': 'san patricio',
#   'Lat': 28.017,
#   'Lng': -97.5169,
#   'Max Temp': 309.19,
#   'Humidity': 41,
#   'Cloudiness': 56,
#   'Wind Speed': 4.39,
#   'Country': 'US',
#   'Date': 1693769158},
#  {'City': 'gorontalo',
#   'Lat': 0.5412,
#   'Lng': 123.0595,
#   'Max Temp': 295.97,
#   'Humidity': 93,
#   'Cloudiness': 39,
#   'Wind Speed': 2.19,
#   'Country': 'ID',
#   'Date': 1693769160},
#  {'City': 'akyab',
#   'Lat': 20.15,
#   'Lng': 92.9,
#   'Max Temp': 299.89,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 4.37,
#   'Country': 'MM',
#   'Date': 1693769160},
#  {'City': 'sao filipe',
#   'Lat': 14.8961,
#   'Lng': -24.4956,
#   'Max Temp': 299.99,
#   'Humidity': 83,
#   'Cloudiness': 50,
#   'Wind Speed': 1.46,
#   'Country': 'CV',
#   'Date': 1693769160},
#  {'City': 'hulan',
#   'Lat': 45.9833,
#   'Lng': 126.6,
#   'Max Temp': 291.21,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 2.15,
#   'Country': 'CN',
#   'Date': 1693769161},
#  {'City': 'hornepayne',
#   'Lat': 49.2138,
#   'Lng': -84.7705,
#   'Max Temp': 304.26,
#   'Humidity': 39,
#   'Cloudiness': 81,
#   'Wind Speed': 4.58,
#   'Country': 'CA',
#   'Date': 1693769161},
#  {'City': 'hurghada',
#   'Lat': 27.2574,
#   'Lng': 33.8129,
#   'Max Temp': 303.42,
#   'Humidity': 36,
#   'Cloudiness': 0,
#   'Wind Speed': 5.05,
#   'Country': 'EG',
#   'Date': 1693769143},
#  {'City': 'bogen',
#   'Lat': 48.9112,
#   'Lng': 12.6896,
#   'Max Temp': 292.08,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 2.36,
#   'Country': 'DE',
#   'Date': 1693769161},
#  {'City': 'maneadero',
#   'Lat': 31.7167,
#   'Lng': -116.5667,
#   'Max Temp': 297.65,
#   'Humidity': 75,
#   'Cloudiness': 36,
#   'Wind Speed': 1.34,
#   'Country': 'MX',
#   'Date': 1693769161},
#  {'City': 'bekhtery',
#   'Lat': 46.251,
#   'Lng': 32.2927,
#   'Max Temp': 294.09,
#   'Humidity': 44,
#   'Cloudiness': 0,
#   'Wind Speed': 2.26,
#   'Country': 'UA',
#   'Date': 1693769161},
#  {'City': 'khatanga',
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp': 274.72,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 5.17,
#   'Country': 'RU',
#   'Date': 1693769162},
#  {'City': 'shatsk',
#   'Lat': 54.0258,
#   'Lng': 41.7119,
#   'Max Temp': 289.29,
#   'Humidity': 73,
#   'Cloudiness': 72,
#   'Wind Speed': 1.15,
#   'Country': 'RU',
#   'Date': 1693769162},
#  {'City': 'purranque',
#   'Lat': -40.9167,
#   'Lng': -73.1667,
#   'Max Temp': 281.78,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 0.64,
#   'Country': 'CL',
#   'Date': 1693769162},
#  {'City': 'margate',
#   'Lat': 51.3813,
#   'Lng': 1.3862,
#   'Max Temp': 293.09,
#   'Humidity': 86,
#   'Cloudiness': 52,
#   'Wind Speed': 0.89,
#   'Country': 'GB',
#   'Date': 1693769162},
#  {'City': 'codrington',
#   'Lat': -38.2667,
#   'Lng': 141.9667,
#   'Max Temp': 289.22,
#   'Humidity': 38,
#   'Cloudiness': 100,
#   'Wind Speed': 9.21,
#   'Country': 'AU',
#   'Date': 1693769162},
#  {'City': 'potosi',
#   'Lat': -19.5836,
#   'Lng': -65.7531,
#   'Max Temp': 287.67,
#   'Humidity': 11,
#   'Cloudiness': 2,
#   'Wind Speed': 11.42,
#   'Country': 'BO',
#   'Date': 1693769163},
#  {'City': 'yulara',
#   'Lat': -25.2406,
#   'Lng': 130.9889,
#   'Max Temp': 286.93,
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 5.64,
#   'Country': 'AU',
#   'Date': 1693769163},
#  {'City': 'new norfolk',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 278.55,
#   'Humidity': 94,
#   'Cloudiness': 0,
#   'Wind Speed': 1.37,
#   'Country': 'AU',
#   'Date': 1693769163},
#  {'City': 'iqaluit',
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp': 277,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 9.26,
#   'Country': 'CA',
#   'Date': 1693769163},
#  {'City': 'umm kaddadah',
#   'Lat': 13.6017,
#   'Lng': 26.6876,
#   'Max Temp': 306.27,
#   'Humidity': 34,
#   'Cloudiness': 50,
#   'Wind Speed': 2.48,
#   'Country': 'SD',
#   'Date': 1693769118},
#  {'City': 'balkanabat',
#   'Lat': 39.5108,
#   'Lng': 54.3671,
#   'Max Temp': 301.11,
#   'Humidity': 29,
#   'Cloudiness': 0,
#   'Wind Speed': 2.45,
#   'Country': 'TM',
#   'Date': 1693769163},
#  {'City': 'saldanha',
#   'Lat': -33.0117,
#   'Lng': 17.9442,
#   'Max Temp': 285.06,
#   'Humidity': 80,
#   'Cloudiness': 11,
#   'Wind Speed': 2.99,
#   'Country': 'ZA',
#   'Date': 1693769163},
#  {'City': 'saint-pierre',
#   'Lat': -21.3393,
#   'Lng': 55.4781,
#   'Max Temp': 292.97,
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind Speed': 3.09,
#   'Country': 'RE',
#   'Date': 1693769164},
#  {'City': 'paamiut',
#   'Lat': 61.994,
#   'Lng': -49.6678,
#   'Max Temp': 277.14,
#   'Humidity': 74,
#   'Cloudiness': 98,
#   'Wind Speed': 5.68,
#   'Country': 'GL',
#   'Date': 1693769164},
#  {'City': 'vila franca do campo',
#   'Lat': 37.7167,
#   'Lng': -25.4333,
#   'Max Temp': 296.38,
#   'Humidity': 61,
#   'Cloudiness': 56,
#   'Wind Speed': 1.12,
#   'Country': 'PT',
#   'Date': 1693769164},
#  {'City': 'lensk',
#   'Lat': 60.7253,
#   'Lng': 114.9278,
#   'Max Temp': 278.58,
#   'Humidity': 78,
#   'Cloudiness': 15,
#   'Wind Speed': 1.19,
#   'Country': 'RU',
#   'Date': 1693769164},
#  {'City': 'emerald',
#   'Lat': -23.5333,
#   'Lng': 148.1667,
#   'Max Temp': 288.9,
#   'Humidity': 86,
#   'Cloudiness': 18,
#   'Wind Speed': 3.21,
#   'Country': 'AU',
#   'Date': 1693769164},
#  {'City': 'russell',
#   'Lat': 32.3502,
#   'Lng': -85.1999,
#   'Max Temp': 305.68,
#   'Humidity': 43,
#   'Cloudiness': 40,
#   'Wind Speed': 3.6,
#   'Country': 'US',
#   'Date': 1693769165},
#  {'City': 'maceio',
#   'Lat': -9.6658,
#   'Lng': -35.7353,
#   'Max Temp': 300.84,
#   'Humidity': 65,
#   'Cloudiness': 20,
#   'Wind Speed': 5.14,
#   'Country': 'BR',
#   'Date': 1693769109},
#  {'City': 'tucuman',
#   'Lat': -26.8241,
#   'Lng': -65.2226,
#   'Max Temp': 287.15,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 2.57,
#   'Country': 'AR',
#   'Date': 1693769165},
#  {'City': 'avera',
#   'Lat': 33.194,
#   'Lng': -82.5271,
#   'Max Temp': 304.31,
#   'Humidity': 33,
#   'Cloudiness': 0,
#   'Wind Speed': 2.07,
#   'Country': 'US',
#   'Date': 1693769165},
#  {'City': 'abengourou',
#   'Lat': 6.7297,
#   'Lng': -3.4964,
#   'Max Temp': 295.41,
#   'Humidity': 99,
#   'Cloudiness': 99,
#   'Wind Speed': 1.67,
#   'Country': 'CI',
#   'Date': 1693769165},
#  {'City': 'touros',
#   'Lat': -5.1989,
#   'Lng': -35.4608,
#   'Max Temp': 300.85,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 7.73,
#   'Country': 'BR',
#   'Date': 1693769166},
#  {'City': 'avarua',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 296.18,
#   'Humidity': 64,
#   'Cloudiness': 84,
#   'Wind Speed': 2.57,
#   'Country': 'CK',
#   'Date': 1693768966},
#  {'City': 'tabas',
#   'Lat': 33.5959,
#   'Lng': 56.9244,
#   'Max Temp': 303.55,
#   'Humidity': 11,
#   'Cloudiness': 0,
#   'Wind Speed': 2.46,
#   'Country': 'IR',
#   'Date': 1693769166},
#  {'City': 'san cristobal',
#   'Lat': 7.7669,
#   'Lng': -72.225,
#   'Max Temp': 303.25,
#   'Humidity': 45,
#   'Cloudiness': 91,
#   'Wind Speed': 4.18,
#   'Country': 'VE',
#   'Date': 1693769166},
#  {'City': 'mount gambier',
#   'Lat': -37.8333,
#   'Lng': 140.7667,
#   'Max Temp': 289.23,
#   'Humidity': 34,
#   'Cloudiness': 99,
#   'Wind Speed': 7.32,
#   'Country': 'AU',
#   'Date': 1693769166},
#  {'City': 'nemuro',
#   'Lat': 43.3236,
#   'Lng': 145.575,
#   'Max Temp': 290.59,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 1.21,
#   'Country': 'JP',
#   'Date': 1693769166},
#  {'City': 'guerrero negro',
#   'Lat': 27.9769,
#   'Lng': -114.0611,
#   'Max Temp': 298.65,
#   'Humidity': 75,
#   'Cloudiness': 34,
#   'Wind Speed': 8.06,
#   'Country': 'MX',
#   'Date': 1693769166},
#  {'City': 'marsh harbour',
#   'Lat': 26.5412,
#   'Lng': -77.0636,
#   'Max Temp': 301.33,
#   'Humidity': 62,
#   'Cloudiness': 13,
#   'Wind Speed': 7.01,
#   'Country': 'BS',
#   'Date': 1693769167},
#  {'City': 'ambon',
#   'Lat': -3.6954,
#   'Lng': 128.1814,
#   'Max Temp': 299.19,
#   'Humidity': 95,
#   'Cloudiness': 40,
#   'Wind Speed': 3.09,
#   'Country': 'ID',
#   'Date': 1693769167},
#  {'City': 'lazaro cardenas',
#   'Lat': 17.9583,
#   'Lng': -102.2,
#   'Max Temp': 304.11,
#   'Humidity': 67,
#   'Cloudiness': 65,
#   'Wind Speed': 2.48,
#   'Country': 'MX',
#   'Date': 1693769167},
#  {'City': 'horki',
#   'Lat': 54.2861,
#   'Lng': 30.9842,
#   'Max Temp': 286.52,
#   'Humidity': 70,
#   'Cloudiness': 8,
#   'Wind Speed': 1.73,
#   'Country': 'BY',
#   'Date': 1693769167},
#  {'City': 'kruisfontein',
#   'Lat': -34.0033,
#   'Lng': 24.7314,
#   'Max Temp': 284.23,
#   'Humidity': 74,
#   'Cloudiness': 15,
#   'Wind Speed': 3.18,
#   'Country': 'ZA',
#   'Date': 1693769167},
#  {'City': 'oksfjord',
#   'Lat': 70.2396,
#   'Lng': 22.3479,
#   'Max Temp': 289.19,
#   'Humidity': 84,
#   'Cloudiness': 87,
#   'Wind Speed': 4.31,
#   'Country': 'NO',
#   'Date': 1693769167},
#  {'City': 'shatoy',
#   'Lat': 42.8714,
#   'Lng': 45.6886,
#   'Max Temp': 292.57,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 2.49,
#   'Country': 'RU',
#   'Date': 1693769169},
#  {'City': 'broome',
#   'Lat': 42.2506,
#   'Lng': -75.833,
#   'Max Temp': 304.36,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 3.13,
#   'Country': 'US',
#   'Date': 1693769169},
#  {'City': 'longyearbyen',
#   'Lat': 78.2186,
#   'Lng': 15.6401,
#   'Max Temp': 278.06,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 2.06,
#   'Country': 'SJ',
#   'Date': 1693768890},
#  {'City': 'salalah',
#   'Lat': 17.0151,
#   'Lng': 54.0924,
#   'Max Temp': 301.2,
#   'Humidity': 89,
#   'Cloudiness': 75,
#   'Wind Speed': 3.6,
#   'Country': 'OM',
#   'Date': 1693769169},
#  {'City': 'snezhnogorsk',
#   'Lat': 69.1933,
#   'Lng': 33.2531,
#   'Max Temp': 287.03,
#   'Humidity': 84,
#   'Cloudiness': 20,
#   'Wind Speed': 4.41,
#   'Country': 'RU',
#   'Date': 1693769169},
#  {'City': 'hirara',
#   'Lat': 24.8,
#   'Lng': 125.2833,
#   'Max Temp': 299.3,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 6.69,
#   'Country': 'JP',
#   'Date': 1693769169},
#  {'City': 'guiratinga',
#   'Lat': -16.3494,
#   'Lng': -53.7583,
#   'Max Temp': 308.04,
#   'Humidity': 29,
#   'Cloudiness': 100,
#   'Wind Speed': 4.88,
#   'Country': 'BR',
#   'Date': 1693769170},
#  {'City': 'kasama',
#   'Lat': -10.2129,
#   'Lng': 31.1808,
#   'Max Temp': 295.69,
#   'Humidity': 29,
#   'Cloudiness': 38,
#   'Wind Speed': 4.01,
#   'Country': 'ZM',
#   'Date': 1693769170},
#  {'City': 'ames',
#   'Lat': 42.0347,
#   'Lng': -93.6199,
#   'Max Temp': 308.12,
#   'Humidity': 32,
#   'Cloudiness': 0,
#   'Wind Speed': 6.69,
#   'Country': 'US',
#   'Date': 1693769170},
#  {'City': 'esmeraldas',
#   'Lat': -19.7625,
#   'Lng': -44.3139,
#   'Max Temp': 302.63,
#   'Humidity': 40,
#   'Cloudiness': 95,
#   'Wind Speed': 2.79,
#   'Country': 'BR',
#   'Date': 1693769170},
#  {'City': 'kavieng',
#   'Lat': -2.5744,
#   'Lng': 150.7967,
#   'Max Temp': 300.42,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 4.18,
#   'Country': 'PG',
#   'Date': 1693769170},
#  {'City': 'saint-francois',
#   'Lat': 46.4154,
#   'Lng': 3.9054,
#   'Max Temp': 297.84,
#   'Humidity': 50,
#   'Cloudiness': 0,
#   'Wind Speed': 1.54,
#   'Country': 'FR',
#   'Date': 1693769170},
#  {'City': 'ahipara',
#   'Lat': -35.1667,
#   'Lng': 173.1667,
#   'Max Temp': 286.94,
#   'Humidity': 95,
#   'Cloudiness': 82,
#   'Wind Speed': 3.1,
#   'Country': 'NZ',
#   'Date': 1693769171},
#  {'City': 'sioux lookout',
#   'Lat': 50.1001,
#   'Lng': -91.917,
#   'Max Temp': 299.19,
#   'Humidity': 47,
#   'Cloudiness': 75,
#   'Wind Speed': 2.57,
#   'Country': 'CA',
#   'Date': 1693769171},
#  {'City': 'huangyan',
#   'Lat': 28.6478,
#   'Lng': 121.2594,
#   'Max Temp': 296.66,
#   'Humidity': 96,
#   'Cloudiness': 96,
#   'Wind Speed': 1.71,
#   'Country': 'CN',
#   'Date': 1693769171},
#  {'City': 'pochutla',
#   'Lat': 15.7432,
#   'Lng': -96.4661,
#   'Max Temp': 304.16,
#   'Humidity': 58,
#   'Cloudiness': 97,
#   'Wind Speed': 3.59,
#   'Country': 'MX',
#   'Date': 1693769171},
#  {'City': 'daru',
#   'Lat': -9.0763,
#   'Lng': 143.2092,
#   'Max Temp': 297.14,
#   'Humidity': 74,
#   'Cloudiness': 67,
#   'Wind Speed': 5.91,
#   'Country': 'PG',
#   'Date': 1693769171},
#  {'City': 'jinxiang',
#   'Lat': 27.4327,
#   'Lng': 120.6062,
#   'Max Temp': 299.01,
#   'Humidity': 87,
#   'Cloudiness': 97,
#   'Wind Speed': 6.72,
#   'Country': 'CN',
#   'Date': 1693769171},
#  {'City': 'sabha',
#   'Lat': 27.0377,
#   'Lng': 14.4283,
#   'Max Temp': 307.98,
#   'Humidity': 14,
#   'Cloudiness': 0,
#   'Wind Speed': 3.32,
#   'Country': 'LY',
#   'Date': 1693769172},
#  {'City': 'lasa',
#   'Lat': 46.6166,
#   'Lng': 10.7002,
#   'Max Temp': 297.64,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind Speed': 2.58,
#   'Country': 'IT',
#   'Date': 1693769172},
#  {'City': 'chokurdakh',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp': 273.77,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 3.37,
#   'Country': 'RU',
#   'Date': 1693769172},
#  {'City': 'sobolevo',
#   'Lat': 54.4299,
#   'Lng': 31.8996,
#   'Max Temp': 285.94,
#   'Humidity': 77,
#   'Cloudiness': 5,
#   'Wind Speed': 2.22,
#   'Country': 'RU',
#   'Date': 1693769172},
#  {'City': 'hofn',
#   'Lat': 64.2539,
#   'Lng': -15.2082,
#   'Max Temp': 282.89,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 15.65,
#   'Country': 'IS',
#   'Date': 1693769172},
#  {'City': 'thinadhoo',
#   'Lat': 0.5333,
#   'Lng': 72.9333,
#   'Max Temp': 300.94,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 1.59,
#   'Country': 'MV',
#   'Date': 1693769172},
#  {'City': 'cherskiy',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': 274.46,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 3.38,
#   'Country': 'RU',
#   'Date': 1693769173},
#  {'City': 'leua',
#   'Lat': 48.2156,
#   'Lng': 18.6071,
#   'Max Temp': 292.31,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 2.99,
#   'Country': 'SK',
#   'Date': 1693769173},
#  {'City': 'benjamin constant',
#   'Lat': -4.3831,
#   'Lng': -70.0311,
#   'Max Temp': 308.22,
#   'Humidity': 58,
#   'Cloudiness': 75,
#   'Wind Speed': 2.06,
#   'Country': 'BR',
#   'Date': 1693769173},
#  {'City': 'jalu',
#   'Lat': 29.0331,
#   'Lng': 21.5482,
#   'Max Temp': 302.87,
#   'Humidity': 25,
#   'Cloudiness': 0,
#   'Wind Speed': 3.7,
#   'Country': 'LY',
#   'Date': 1693769173},
#  {'City': 'san jose',
#   'Lat': 37.3394,
#   'Lng': -121.895,
#   'Max Temp': 297.46,
#   'Humidity': 61,
#   'Cloudiness': 75,
#   'Wind Speed': 4.47,
#   'Country': 'US',
#   'Date': 1693768988},
#  {'City': 'vila velha',
#   'Lat': -20.3297,
#   'Lng': -40.2925,
#   'Max Temp': 299.12,
#   'Humidity': 81,
#   'Cloudiness': 20,
#   'Wind Speed': 7.2,
#   'Country': 'BR',
# ...
#   'Lng': 29.1458,
#   'Max Temp': 299.2,
#   'Humidity': 67,
#   'Cloudiness': 32,
#   'Wind Speed': 1.23,
#   'Country': 'CD',
#   'Date': 1693769219},
#  {'City': 'pangnirtung',
#   'Lat': 66.1451,
#   'Lng': -65.7125,
#   'Max Temp': 278.15,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 10.29,
#   'Country': 'CA',
#   'Date': 1693769219},
#  {'City': 'kiunga',
#   'Lat': -6.1219,
#   'Lng': 141.2906,
#   'Max Temp': 294.93,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 1.34,
#   'Country': 'PG',
#   'Date': 1693769219},
#  {'City': 'alta floresta',
#   'Lat': -9.8756,
#   'Lng': -56.0861,
#   'Max Temp': 309.05,
#   'Humidity': 38,
#   'Cloudiness': 40,
#   'Wind Speed': 3.09,
#   'Country': 'BR',
#   'Date': 1693769219},
#  {'City': 'amga',
#   'Lat': 60.8953,
#   'Lng': 131.9608,
#   'Max Temp': 275.47,
#   'Humidity': 91,
#   'Cloudiness': 20,
#   'Wind Speed': 1.6,
#   'Country': 'RU',
#   'Date': 1693769220},
#  {'City': 'carballo',
#   'Lat': 43.213,
#   'Lng': -8.691,
#   'Max Temp': 297.46,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 1.83,
#   'Country': 'ES',
#   'Date': 1693769220},
#  {'City': 'isetskoye',
#   'Lat': 56.4858,
#   'Lng': 65.3226,
#   'Max Temp': 285.96,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 5.29,
#   'Country': 'RU',
#   'Date': 1693769220},
#  {'City': 'ormara',
#   'Lat': 25.2088,
#   'Lng': 64.6357,
#   'Max Temp': 299.37,
#   'Humidity': 84,
#   'Cloudiness': 0,
#   'Wind Speed': 5.09,
#   'Country': 'PK',
#   'Date': 1693769220},
#  {'City': 'camacupa',
#   'Lat': -12.0167,
#   'Lng': 17.4833,
#   'Max Temp': 295.39,
#   'Humidity': 13,
#   'Cloudiness': 94,
#   'Wind Speed': 1.79,
#   'Country': 'AO',
#   'Date': 1693769220},
#  {'City': 'beberibe',
#   'Lat': -4.1797,
#   'Lng': -38.1306,
#   'Max Temp': 301.48,
#   'Humidity': 64,
#   'Cloudiness': 5,
#   'Wind Speed': 5.86,
#   'Country': 'BR',
#   'Date': 1693769220},
#  {'City': 'bacolod',
#   'Lat': 10.6667,
#   'Lng': 122.95,
#   'Max Temp': 299.05,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 5.15,
#   'Country': 'PH',
#   'Date': 1693769220},
#  {'City': 'humberto de campos',
#   'Lat': -2.5983,
#   'Lng': -43.4611,
#   'Max Temp': 303.9,
#   'Humidity': 55,
#   'Cloudiness': 26,
#   'Wind Speed': 5.43,
#   'Country': 'BR',
#   'Date': 1693769221},
#  {'City': 'beisfjord',
#   'Lat': 68.3751,
#   'Lng': 17.5988,
#   'Max Temp': 287.62,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 0.97,
#   'Country': 'NO',
#   'Date': 1693769221},
#  {'City': 'gat',
#   'Lat': 31.61,
#   'Lng': 34.7642,
#   'Max Temp': 299.71,
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind Speed': 2.08,
#   'Country': 'IL',
#   'Date': 1693769221},
#  {'City': 'uspenka',
#   'Lat': 48.3903,
#   'Lng': 39.1619,
#   'Max Temp': 296.19,
#   'Humidity': 42,
#   'Cloudiness': 73,
#   'Wind Speed': 2.64,
#   'Country': 'UA',
#   'Date': 1693769221},
#  {'City': 'hambantota',
#   'Lat': 6.1241,
#   'Lng': 81.1185,
#   'Max Temp': 298.75,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 8.18,
#   'Country': 'LK',
#   'Date': 1693769221},
#  {'City': 'paso de los toros',
#   'Lat': -32.8167,
#   'Lng': -56.5167,
#   'Max Temp': 287.52,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 5.6,
#   'Country': 'UY',
#   'Date': 1693769221},
#  {'City': 'poum',
#   'Lat': -20.2333,
#   'Lng': 164.0167,
#   'Max Temp': 294.12,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 2.66,
#   'Country': 'NC',
#   'Date': 1693769222},
#  {'City': 'lompoc',
#   'Lat': 34.6391,
#   'Lng': -120.4579,
#   'Max Temp': 298.71,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 3.58,
#   'Country': 'US',
#   'Date': 1693769222},
#  {'City': 'pisco',
#   'Lat': -13.7,
#   'Lng': -76.2167,
#   'Max Temp': 295.18,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 5.66,
#   'Country': 'PE',
#   'Date': 1693769079},
#  {'City': 'yining',
#   'Lat': 29.0361,
#   'Lng': 114.5636,
#   'Max Temp': 293.61,
#   'Humidity': 88,
#   'Cloudiness': 72,
#   'Wind Speed': 1.16,
#   'Country': 'CN',
#   'Date': 1693769222},
#  {'City': 'syracuse',
#   'Lat': 37.0881,
#   'Lng': 15.2792,
#   'Max Temp': 299.92,
#   'Humidity': 65,
#   'Cloudiness': 6,
#   'Wind Speed': 1.8,
#   'Country': 'IT',
#   'Date': 1693769222},
#  {'City': 'tahoua',
#   'Lat': 14.8888,
#   'Lng': 5.2692,
#   'Max Temp': 305.34,
#   'Humidity': 45,
#   'Cloudiness': 7,
#   'Wind Speed': 3.9,
#   'Country': 'NE',
#   'Date': 1693769223},
#  {'City': 'mattru',
#   'Lat': 7.6244,
#   'Lng': -11.8332,
#   'Max Temp': 296.56,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 2.42,
#   'Country': 'SL',
#   'Date': 1693769223},
#  {'City': 'brae',
#   'Lat': 60.3964,
#   'Lng': -1.353,
#   'Max Temp': 286.69,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 5.8,
#   'Country': 'GB',
#   'Date': 1693769223},
#  {'City': 'vallenar',
#   'Lat': -28.5708,
#   'Lng': -70.7581,
#   'Max Temp': 294.72,
#   'Humidity': 29,
#   'Cloudiness': 30,
#   'Wind Speed': 5.46,
#   'Country': 'CL',
#   'Date': 1693769223},
#  {'City': 'indiana',
#   'Lat': 40.0003,
#   'Lng': -86.2503,
#   'Max Temp': 305.35,
#   'Humidity': 56,
#   'Cloudiness': 40,
#   'Wind Speed': 5.14,
#   'Country': 'US',
#   'Date': 1693769223},
#  {'City': 'ofunato',
#   'Lat': 39.0717,
#   'Lng': 141.7167,
#   'Max Temp': 297.76,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 1.02,
#   'Country': 'JP',
#   'Date': 1693769224},
#  {'City': 'baruun-urt',
#   'Lat': 46.6806,
#   'Lng': 113.2792,
#   'Max Temp': 285.61,
#   'Humidity': 95,
#   'Cloudiness': 13,
#   'Wind Speed': 3.42,
#   'Country': 'MN',
#   'Date': 1693769224},
#  {'City': 'moose factory',
#   'Lat': 51.2585,
#   'Lng': -80.6094,
#   'Max Temp': 303.15,
#   'Humidity': 48,
#   'Cloudiness': 75,
#   'Wind Speed': 6.17,
#   'Country': 'CA',
#   'Date': 1693769224},
#  {'City': 'vestmannaeyjar',
#   'Lat': 63.4427,
#   'Lng': -20.2734,
#   'Max Temp': 282.36,
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 13.4,
#   'Country': 'IS',
#   'Date': 1693769224},
#  {'City': 'samfya',
#   'Lat': -11.3649,
#   'Lng': 29.5565,
#   'Max Temp': 296.81,
#   'Humidity': 29,
#   'Cloudiness': 3,
#   'Wind Speed': 4.79,
#   'Country': 'ZM',
#   'Date': 1693769225},
#  {'City': 'kurilsk',
#   'Lat': 45.2333,
#   'Lng': 147.8833,
#   'Max Temp': 290.37,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 0.46,
#   'Country': 'RU',
#   'Date': 1693769226},
#  {'City': 'miri',
#   'Lat': 4.4148,
#   'Lng': 114.0089,
#   'Max Temp': 298.23,
#   'Humidity': 100,
#   'Cloudiness': 20,
#   'Wind Speed': 1.03,
#   'Country': 'MY',
#   'Date': 1693769010},
#  {'City': 'ambilobe',
#   'Lat': -13.2,
#   'Lng': 49.05,
#   'Max Temp': 294.32,
#   'Humidity': 69,
#   'Cloudiness': 45,
#   'Wind Speed': 2.13,
#   'Country': 'MG',
#   'Date': 1693769228},
#  {'City': 'zhigalovo',
#   'Lat': 54.8097,
#   'Lng': 105.1578,
#   'Max Temp': 280.17,
#   'Humidity': 65,
#   'Cloudiness': 81,
#   'Wind Speed': 0.62,
#   'Country': 'RU',
#   'Date': 1693769228},
#  {'City': 'tazovskiy',
#   'Lat': 67.4667,
#   'Lng': 78.7,
#   'Max Temp': 277.07,
#   'Humidity': 82,
#   'Cloudiness': 36,
#   'Wind Speed': 4.94,
#   'Country': 'RU',
#   'Date': 1693769228},
#  {'City': 'dzilam gonzalez',
#   'Lat': 21.2833,
#   'Lng': -88.9333,
#   'Max Temp': 306.5,
#   'Humidity': 53,
#   'Cloudiness': 97,
#   'Wind Speed': 5.17,
#   'Country': 'MX',
#   'Date': 1693769229},
#  {'City': 'lamar',
#   'Lat': 33.6668,
#   'Lng': -95.5836,
#   'Max Temp': 312.58,
#   'Humidity': 41,
#   'Cloudiness': 40,
#   'Wind Speed': 4.63,
#   'Country': 'US',
#   'Date': 1693769229},
#  {'City': 'chicama',
#   'Lat': -7.8447,
#   'Lng': -79.1469,
#   'Max Temp': 294.45,
#   'Humidity': 62,
#   'Cloudiness': 24,
#   'Wind Speed': 5.21,
#   'Country': 'PE',
#   'Date': 1693769229},
#  {'City': 'pevek',
#   'Lat': 69.7008,
#   'Lng': 170.3133,
#   'Max Temp': 273.86,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 4.97,
#   'Country': 'RU',
#   'Date': 1693769229},
#  {'City': 'trzcianka',
#   'Lat': 53.0406,
#   'Lng': 16.4563,
#   'Max Temp': 288.94,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind Speed': 3.23,
#   'Country': 'PL',
#   'Date': 1693769229},
#  {'City': 'imeni poliny osipenko',
#   'Lat': 52.4201,
#   'Lng': 136.4853,
#   'Max Temp': 278.11,
#   'Humidity': 78,
#   'Cloudiness': 6,
#   'Wind Speed': 0.79,
#   'Country': 'RU',
#   'Date': 1693769229},
#  {'City': 'aykhal',
#   'Lat': 66,
#   'Lng': 111.5,
#   'Max Temp': 278.22,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 3.49,
#   'Country': 'RU',
#   'Date': 1693769230},
#  {'City': 'qarayeri',
#   'Lat': 40.7886,
#   'Lng': 46.3066,
#   'Max Temp': 299.64,
#   'Humidity': 50,
#   'Cloudiness': 40,
#   'Wind Speed': 8.23,
#   'Country': 'AZ',
#   'Date': 1693769230},
#  {'City': 'necochea',
#   'Lat': -38.5473,
#   'Lng': -58.7368,
#   'Max Temp': 282.92,
#   'Humidity': 62,
#   'Cloudiness': 100,
#   'Wind Speed': 5.32,
#   'Country': 'AR',
#   'Date': 1693768978},
#  {'City': 'huadian',
#   'Lat': 42.9633,
#   'Lng': 126.7478,
#   'Max Temp': 288.42,
#   'Humidity': 88,
#   'Cloudiness': 30,
#   'Wind Speed': 1.07,
#   'Country': 'CN',
#   'Date': 1693769230},
#  {'City': 'henties bay',
#   'Lat': -22.116,
#   'Lng': 14.2845,
#   'Max Temp': 285.84,
#   'Humidity': 79,
#   'Cloudiness': 0,
#   'Wind Speed': 4.43,
#   'Country': 'NA',
#   'Date': 1693769230},
#  {'City': 'kuusamo',
#   'Lat': 65.9667,
#   'Lng': 29.1833,
#   'Max Temp': 287.17,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 4.63,
#   'Country': 'FI',
#   'Date': 1693769231},
#  {'City': 'derzhavinsk',
#   'Lat': 51.1,
#   'Lng': 66.3167,
#   'Max Temp': 285.8,
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind Speed': 7.44,
#   'Country': 'KZ',
#   'Date': 1693769231},
#  {'City': 'saravan',
#   'Lat': 39.7196,
#   'Lng': 45.6483,
#   'Max Temp': 290.93,
#   'Humidity': 66,
#   'Cloudiness': 7,
#   'Wind Speed': 3.5,
#   'Country': 'AM',
#   'Date': 1693769231},
#  {'City': 'puerto escondido',
#   'Lat': 15.85,
#   'Lng': -97.0667,
#   'Max Temp': 297.61,
#   'Humidity': 69,
#   'Cloudiness': 75,
#   'Wind Speed': 2.57,
#   'Country': 'MX',
#   'Date': 1693769231},
#  {'City': 'wana',
#   'Lat': 32.2989,
#   'Lng': 69.5725,
#   'Max Temp': 299.88,
#   'Humidity': 38,
#   'Cloudiness': 0,
#   'Wind Speed': 1.16,
#   'Country': 'PK',
#   'Date': 1693769231},
#  {'City': 'svetlyy',
#   'Lat': 54.675,
#   'Lng': 20.1347,
#   'Max Temp': 289.24,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 3.52,
#   'Country': 'RU',
#   'Date': 1693769232},
#  {'City': 'sandviken',
#   'Lat': 60.6167,
#   'Lng': 16.7667,
#   'Max Temp': 285.68,
#   'Humidity': 91,
#   'Cloudiness': 68,
#   'Wind Speed': 2.25,
#   'Country': 'SE',
#   'Date': 1693769232},
#  {'City': 'debre tabor',
#   'Lat': 11.85,
#   'Lng': 38.0167,
#   'Max Temp': 285.42,
#   'Humidity': 79,
#   'Cloudiness': 44,
#   'Wind Speed': 2.34,
#   'Country': 'ET',
#   'Date': 1693769232},
#  {'City': 'chiredzi',
#   'Lat': -21.05,
#   'Lng': 31.6667,
#   'Max Temp': 295.17,
#   'Humidity': 35,
#   'Cloudiness': 2,
#   'Wind Speed': 2.92,
#   'Country': 'ZW',
#   'Date': 1693769232},
#  {'City': 'tolaga bay',
#   'Lat': -38.3667,
#   'Lng': 178.3,
#   'Max Temp': 283.79,
#   'Humidity': 85,
#   'Cloudiness': 99,
#   'Wind Speed': 1.28,
#   'Country': 'NZ',
#   'Date': 1693769232},
#  {'City': 'edd',
#   'Lat': 13.9297,
#   'Lng': 41.6925,
#   'Max Temp': 306.14,
#   'Humidity': 66,
#   'Cloudiness': 36,
#   'Wind Speed': 2.14,
#   'Country': 'ER',
#   'Date': 1693769233},
#  {'City': 'zubova polyana',
#   'Lat': 54.0771,
#   'Lng': 42.8372,
#   'Max Temp': 289.49,
#   'Humidity': 56,
#   'Cloudiness': 96,
#   'Wind Speed': 2.07,
#   'Country': 'RU',
#   'Date': 1693769233},
#  {'City': 'bulungu',
#   'Lat': -4.55,
#   'Lng': 18.6,
#   'Max Temp': 299.6,
#   'Humidity': 58,
#   'Cloudiness': 62,
#   'Wind Speed': 2.99,
#   'Country': 'CD',
#   'Date': 1693769233},
#  {'City': 'kyaikkami',
#   'Lat': 16.08,
#   'Lng': 97.5675,
#   'Max Temp': 299.99,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 3.71,
#   'Country': 'MM',
#   'Date': 1693769233},
#  {'City': 'port augusta',
#   'Lat': -32.5,
#   'Lng': 137.7667,
#   'Max Temp': 286.15,
#   'Humidity': 77,
#   'Cloudiness': 85,
#   'Wind Speed': 3.62,
#   'Country': 'AU',
#   'Date': 1693769233},
#  {'City': 'hope',
#   'Lat': 33.6671,
#   'Lng': -93.5916,
#   'Max Temp': 308.14,
#   'Humidity': 37,
#   'Cloudiness': 95,
#   'Wind Speed': 1.91,
#   'Country': 'US',
#   'Date': 1693769085},
#  {'City': 'arlit',
#   'Lat': 18.7369,
#   'Lng': 7.3853,
#   'Max Temp': 310.31,
#   'Humidity': 26,
#   'Cloudiness': 96,
#   'Wind Speed': 1.54,
#   'Country': 'NE',
#   'Date': 1693769233},
#  {'City': 'leh',
#   'Lat': 34.1667,
#   'Lng': 77.5833,
#   'Max Temp': 288.14,
#   'Humidity': 32,
#   'Cloudiness': 48,
#   'Wind Speed': 2.28,
#   'Country': 'IN',
#   'Date': 1693769234},
#  {'City': 'general roca',
#   'Lat': -39.0333,
#   'Lng': -67.5833,
#   'Max Temp': 286.55,
#   'Humidity': 20,
#   'Cloudiness': 0,
#   'Wind Speed': 4.38,
#   'Country': 'AR',
#   'Date': 1693769234},
#  {'City': 'toora-khem',
#   'Lat': 52.4675,
#   'Lng': 96.11,
#   'Max Temp': 280.96,
#   'Humidity': 92,
#   'Cloudiness': 20,
#   'Wind Speed': 0.78,
#   'Country': 'RU',
#   'Date': 1693769234},
#  {'City': 'tual',
#   'Lat': -5.6667,
#   'Lng': 132.75,
#   'Max Temp': 297.96,
#   'Humidity': 80,
#   'Cloudiness': 99,
#   'Wind Speed': 7.61,
#   'Country': 'ID',
#   'Date': 1693769234},
#  {'City': 'roald',
#   'Lat': 62.5833,
#   'Lng': 6.1333,
#   'Max Temp': 289.44,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 11.32,
#   'Country': 'NO',
#   'Date': 1693769235},
#  {'City': 'urengoy',
#   'Lat': 65.9667,
#   'Lng': 78.3667,
#   'Max Temp': 278.77,
#   'Humidity': 64,
#   'Cloudiness': 61,
#   'Wind Speed': 3.13,
#   'Country': 'RU',
#   'Date': 1693769235},
#  {'City': 'husavik',
#   'Lat': 66.0449,
#   'Lng': -17.3389,
#   'Max Temp': 283.56,
#   'Humidity': 56,
#   'Cloudiness': 100,
#   'Wind Speed': 5.33,
#   'Country': 'IS',
#   'Date': 1693769235},
#  {'City': 'adrar',
#   'Lat': 20.5022,
#   'Lng': -10.0711,
#   'Max Temp': 309.47,
#   'Humidity': 18,
#   'Cloudiness': 0,
#   'Wind Speed': 3.55,
#   'Country': 'MR',
#   'Date': 1693769235},
#  {'City': 'vega de alatorre',
#   'Lat': 20.0333,
#   'Lng': -96.6333,
#   'Max Temp': 304.17,
#   'Humidity': 60,
#   'Cloudiness': 96,
#   'Wind Speed': 3.79,
#   'Country': 'MX',
#   'Date': 1693769236},
#  {'City': 'quesnel',
#   'Lat': 52.9999,
#   'Lng': -122.5029,
#   'Max Temp': 287.43,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 0,
#   'Country': 'CA',
#   'Date': 1693769236},
#  {'City': 'kamina',
#   'Lat': -8.7386,
#   'Lng': 24.9906,
#   'Max Temp': 296.77,
#   'Humidity': 43,
#   'Cloudiness': 3,
#   'Wind Speed': 1.38,
#   'Country': 'CD',
#   'Date': 1693769237},
#  {'City': 'northam',
#   'Lat': 51.0333,
#   'Lng': -4.2167,
#   'Max Temp': 294.4,
#   'Humidity': 84,
#   'Cloudiness': 89,
#   'Wind Speed': 3.13,
#   'Country': 'GB',
#   'Date': 1693769237},
#  {'City': 'prado',
#   'Lat': -17.3411,
#   'Lng': -39.2208,
#   'Max Temp': 297.53,
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 3.27,
#   'Country': 'BR',
#   'Date': 1693769208},
#  {'City': 'mananjary',
#   'Lat': -21.2167,
#   'Lng': 48.3333,
#   'Max Temp': 293.63,
#   'Humidity': 85,
#   'Cloudiness': 0,
#   'Wind Speed': 0.93,
#   'Country': 'MG',
#   'Date': 1693769237},
#  {'City': 'rosetown',
#   'Lat': 51.5501,
#   'Lng': -108.0014,
#   'Max Temp': 300.14,
#   'Humidity': 22,
#   'Cloudiness': 100,
#   'Wind Speed': 7.2,
#   'Country': 'CA',
#   'Date': 1693769238},
#  {'City': 'zhenlai',
#   'Lat': 45.8495,
#   'Lng': 123.2973,
#   'Max Temp': 286.44,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 5.02,
#   'Country': 'CN',
#   'Date': 1693769238},
#  {'City': 'tuy hoa',
#   'Lat': 13.0833,
#   'Lng': 109.3,
#   'Max Temp': 299.34,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 2.76,
#   'Country': 'VN',
#   'Date': 1693769238},
#  {'City': 'iquitos',
#   'Lat': -3.7481,
#   'Lng': -73.2472,
#   'Max Temp': 306.17,
#   'Humidity': 55,
#   'Cloudiness': 40,
#   'Wind Speed': 3.09,
#   'Country': 'PE',
#   'Date': 1693769238},
#  {'City': 'ihosy',
#   'Lat': -22.4,
#   'Lng': 46.1167,
#   'Max Temp': 290.09,
#   'Humidity': 88,
#   'Cloudiness': 58,
#   'Wind Speed': 4.27,
#   'Country': 'MG',
#   'Date': 1693769238},
#  {'City': 'ngama',
#   'Lat': 11.7833,
#   'Lng': 17.1667,
#   'Max Temp': 297.14,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 1.87,
#   'Country': 'TD',
#   'Date': 1693769238},
#  {'City': 'santiago de cao',
#   'Lat': -7.9589,
#   'Lng': -79.2392,
#   'Max Temp': 295.22,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 3.6,
#   'Country': 'PE',
#   'Date': 1693769239},
#  {'City': 'zalantun',
#   'Lat': 48,
#   'Lng': 122.7167,
#   'Max Temp': 281.68,
#   'Humidity': 83,
#   'Cloudiness': 81,
#   'Wind Speed': 2.68,
#   'Country': 'CN',
#   'Date': 1693769239},
#  {'City': 'kahului',
#   'Lat': 20.8947,
#   'Lng': -156.47,
#   'Max Temp': 301.16,
#   'Humidity': 66,
#   'Cloudiness': 20,
#   'Wind Speed': 9.77,
#   'Country': 'US',
#   'Date': 1693768952}]

# %%
# Convert the cities weather data into a Pandas DataFrame
df_city_data = pd.DataFrame(list_city_data) #dataframe for storing [city_data] data in a more easily data manipulated and visualized format

# Show Record Count
df_city_data.count() #confirms the number of distinct cities pulled from the API request
# Out:
# City          564
# Lat           564
# Lng           564
# Max Temp      564
# Humidity      564
# Cloudiness    564
# Wind Speed    564
# Country       564
# Date          564
# dtype: int64

# %%
# Display sample data
df_city_data.head() # output values of [df_city_data] dataframe
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       rikitea -23.1203 -134.9692    292.77        78         100
# 1         havre  49.5833    0.3333    297.37        83           0
# 2      thompson  55.7435  -97.8558    294.24        46         100
# 3  rondonopolis -16.4708  -54.6356    309.80        27         100
# 4       mataura -46.1927  168.8643    280.64        98          47
#
#    Wind Speed Country        Date
# 0        4.60      PF  1693769122
# 1        4.63      FR  1693769122
# 2        6.69      CA  1693769018
# 3        3.75      BR  1693769122
# 4        1.34      NZ  1693769122

# %%
# Export the [df_city_data] dataframe into a csv
df_city_data.to_csv("../output/cities.csv", index_label="City_ID")

# %% [markdown]
# # NOTE:
# - to make this code platform independent, relpace these relative paths with commands from the `os` library, which ensures it will work on non Unix-based operating systems.
#
# import os
#
# ##### Ensure the directory exists
# output_dir = "../output"
# if not os.path.exists(output_dir):
#     os.makedirs(output_dir)
#
# ##### Create the full path to the CSV file
# csv_path = os.path.join(output_dir, "cities.csv")
#
# ##### Write to CSV
# df_city_data.to_csv(csv_path, index_label="City_ID")

# %%
# Read saved data
df_city_data = pd.read_csv("../output/cities.csv", index_col="City_ID")

# Display sample data
df_city_data.head() # verifying the read in data is the same as the exported data
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             rikitea -23.1203 -134.9692    292.77        78         100
# 1               havre  49.5833    0.3333    297.37        83           0
# 2            thompson  55.7435  -97.8558    294.24        46         100
# 3        rondonopolis -16.4708  -54.6356    309.80        27         100
# 4             mataura -46.1927  168.8643    280.64        98          47
#
#          Wind Speed Country        Date
# City_ID
# 0              4.60      PF  1693769122
# 1              4.63      FR  1693769122
# 2              6.69      CA  1693769018
# 3              3.75      BR  1693769122
# 4              1.34      NZ  1693769122

# %%
# Rename [df_city_data] dataframe column
df_city_data.rename(columns={'Max Temp':'Max Temp (°K)'}, inplace=True)

# Convert df_city_data[Max Temp] column temperature values from (ºK) to (ºC)
df_city_data['Max Temp (°C)'] = df_city_data['Max Temp (°K)'] - 273.15

# Create a list to store the reordered columns
list_ordered_columns = [
    'City',
    'Lat',
    'Lng',
    'Max Temp (°K)',
    'Max Temp (°C)',  # Place it next to 'Max Temp (°K)'
    'Humidity',
    'Cloudiness',
    'Wind Speed',
    'Country',
    'Date'
]

# Reorder the DataFrame columns
df_city_data = df_city_data[list_ordered_columns]


# Display sample data
df_city_data.head() # verifying the read in data is the same as the exported data
# Out:
#                  City      Lat       Lng  Max Temp (°K)  Max Temp (°C)  \
# City_ID
# 0             rikitea -23.1203 -134.9692         292.77          19.62
# 1               havre  49.5833    0.3333         297.37          24.22
# 2            thompson  55.7435  -97.8558         294.24          21.09
# 3        rondonopolis -16.4708  -54.6356         309.80          36.65
# 4             mataura -46.1927  168.8643         280.64           7.49
#
#          Humidity  Cloudiness  Wind Speed Country        Date
# City_ID
# 0              78         100        4.60      PF  1693769122
# 1              83           0        4.63      FR  1693769122
# 2              46         100        6.69      CA  1693769018
# 3              27         100        3.75      BR  1693769122
# 4              98          47        1.34      NZ  1693769122

# %% [markdown]
# ### Visualize the Geographic Weather Data
# ---
# #### Latitude Vs. Temperature
# ---

# %%
# Quadratic fit
def quadratic_function(x, a, b, c):
    return a * x**2 + b * x + c

params, params_covariance = curve_fit(quadratic_function, df_city_data['Lat'], df_city_data['Max Temp (°C)'])
df_city_data['Quadratic_Fit'] = quadratic_function(df_city_data['Lat'], params[0], params[1], params[2])
df_city_data['Distance from Quadratic'] = np.abs(df_city_data['Max Temp (°C)'] - df_city_data['Quadratic_Fit'])

# Scatter plot
fig = px.scatter(df_city_data, x='Lat', y='Max Temp (°C)',
                 color='Distance from Quadratic',  # New distance
                 hover_data=['City'],
                 title='City Latitude vs. Temperature',
                 labels={'Lat': 'Latitude', 'Max Temp (°C)': 'Max Temperature (°C)'}
                 )

# Quadratic regression line
x_values_poly = np.linspace(df_city_data['Lat'].min(), df_city_data['Lat'].max(), 100)
y_values_poly = quadratic_function(x_values_poly, params[0], params[1], params[2])
fig.add_trace(go.Scatter(x=x_values_poly, y=y_values_poly, mode='lines', name='2nd Order Regression Line', line=dict(color='green')))

# Legend arrangement
fig.update_layout(
    legend=dict(
        x=0.5,
        y=1.1,
        traceorder="normal",
        orientation="h"
    )
)

# Show the plot
fig.show()

# Save the figure to [.png] and [.html] files
fig.write_image("../images/latitude-vs-temperature-plotly.png")
fig.write_html("../images/latitude-vs-temperature-plotly.html")

# %% [markdown]
# # Next Steps:
# - Bring over code from VacationPy.ipynb
# - Generate plotly plots like above (maybe type plotly.fig for better documentation or state which library it is from in comments)
# - Add comments to Matplotlib plots
# - Export all visuals to image files accessible in GitHub images folder
# - Convert Jupyter Notebook to HTMl to post on GitHub Pages
# - First, display the story and visualiztion results (maybe this will require JavaScript?)
# - Lastly, record myself on Zoom.
# - Share code and transcription to GPT4 (Maybe a plugin will help analyze it?)
# - Ask for feedback
# - Check status of TxSt applications
# - Apply to Capital Factory Dream Job
# - Apply to other jobs
# - Improve GitHub for 'To Show How 'To Tell a Story'' presentation
# - 200 Pushups

# %%
df_city_data.head()
# Out:
#                  City      Lat       Lng  Max Temp (°K)  Max Temp (°C)  \
# City_ID
# 0             rikitea -23.1203 -134.9692         292.77          19.62
# 1               havre  49.5833    0.3333         297.37          24.22
# 2            thompson  55.7435  -97.8558         294.24          21.09
# 3        rondonopolis -16.4708  -54.6356         309.80          36.65
# 4             mataura -46.1927  168.8643         280.64           7.49
#
#          Humidity  Cloudiness  Wind Speed Country        Date  Quadratic_Fit  \
# City_ID
# 0              78         100        4.60      PF  1693769122      20.340447
# 1              83           0        4.63      FR  1693769122      18.810168
# 2              46         100        6.69      CA  1693769018      15.223187
# 3              27         100        3.75      BR  1693769122      23.326249
# 4              98          47        1.34      NZ  1693769122       5.100139
#
#          Distance from Quadratic
# City_ID
# 0                       0.720447
# 1                       5.409832
# 2                       5.866813
# 3                      13.323751
# 4                       2.389861

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(df_city_data['Lat'], df_city_data['Max Temp (°C)'])

# Incorporate the other graph properties
plt.title('Latitude vs. Temperature')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (°C)')

# Save the figure
plt.savefig("../images/latitude-vs-temperature-matplotlib.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build scatter plot for latitude vs. humidity
plt.scatter(df_city_data['Lat'], df_city_data['Humidity'])

# Incorporate the other graph properties
plt.title('City Latitude vs. Humidity (2023-05-12)')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')

# Save the figure
plt.savefig("../images/latitude-vs-humidity-matplotlib.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build scatter plot for latitude vs. cloudiness
plt.scatter(df_city_data['Lat'], df_city_data['Cloudiness'])

# Incorporate the other graph properties
plt.title('City Latitude vs. Cloudiness (2023-05-12)')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')

# Save the figure
plt.savefig("../images/latitude-vs-cloudiness-matplotlib.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build scatter plot for latitude vs. wind speed
plt.scatter(df_city_data['Lat'], df_city_data['Wind Speed'])

# Incorporate the other graph properties
plt.title('City Latitude vs. Wind Speed (2023-05-12)')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')

# Save the figure
plt.savefig("../images/latitude-vs-windspeed-matplotlib.png")

# Show plot
plt.show()

# %% [markdown]
# ---
# ## Define Function: Linear Regression

# %%
# Define a function to create Linear Regression plots
def create_linear_regression_plot(parameter_1, parameter_2, text_x=0.05, text_y=0.1):
    slope, intercept = np.polyfit(parameter_1, parameter_2, 1)
    r_value = np.corrcoef(parameter_1, parameter_2)[0, 1]

    plt.scatter(parameter_1, parameter_2)
    regression_line = slope * np.array(parameter_1) + intercept
    plt.plot(parameter_1, regression_line, color='red')

    plt.title('Linear Regression Plot')
    plt.xlabel('X')
    plt.ylabel('Y')

    equation = f'y = {slope:.2f}x + {intercept:.2f}'
    plt.text(text_x, text_y, equation, ha='left', va='bottom', transform=plt.gca().transAxes, fontsize=14, fontweight='normal', color='red')

    print(f'r-value: {r_value:.2f}')

    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
df_northern_hemisphere = df_city_data[df_city_data['Lat']>=0]

# Display sample data
df_northern_hemisphere.head()
# Out:
#              City      Lat      Lng  Max Temp (°K)  Max Temp (°C)  Humidity  \
# City_ID
# 1           havre  49.5833   0.3333         297.37          24.22        83
# 2        thompson  55.7435 -97.8558         294.24          21.09        46
# 5          albany  42.6001 -73.9662         303.12          29.97        59
# 7        westport  41.1415 -73.3579         305.98          32.83        57
# 8           limon  10.0000 -83.0333         303.74          30.59        70
#
#          Cloudiness  Wind Speed Country        Date  Quadratic_Fit  \
# City_ID
# 1                 0        4.63      FR  1693769122      18.810168
# 2               100        6.69      CA  1693769018      15.223187
# 5                 3        0.89      US  1693768844      22.223195
# 7                 0        6.69      US  1693769123      22.848455
# 8               100        3.00      CR  1693768964      28.973148
#
#          Distance from Quadratic
# City_ID
# 1                       5.409832
# 2                       5.866813
# 5                       7.746805
# 7                       9.981545
# 8                       1.616852

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
df_southern_hemisphere = df_city_data[df_city_data['Lat']<0]

# Display sample data
df_southern_hemisphere.head()
# Out:
#                  City      Lat       Lng  Max Temp (°K)  Max Temp (°C)  \
# City_ID
# 0             rikitea -23.1203 -134.9692         292.77          19.62
# 3        rondonopolis -16.4708  -54.6356         309.80          36.65
# 4             mataura -46.1927  168.8643         280.64           7.49
# 6            mercedes -34.6515  -59.4307         282.51           9.36
# 11       puerto ayora  -0.7393  -90.3518         303.13          29.98
#
#          Humidity  Cloudiness  Wind Speed Country        Date  Quadratic_Fit  \
# City_ID
# 0              78         100        4.60      PF  1693769122      20.340447
# 3              27         100        3.75      BR  1693769122      23.326249
# 4              98          47        1.34      NZ  1693769122       5.100139
# 6              95         100        6.72      AR  1693769096      13.670689
# 11             90          41        3.58      EC  1693768832      27.884482
#
#          Distance from Quadratic
# City_ID
# 0                       0.720447
# 3                      13.323751
# 4                       2.389861
# 6                       4.310689
# 11                      2.095518

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x = df_northern_hemisphere['Lat']  # X-axis data (latitude)
y = df_northern_hemisphere['Max Temp (°C)']  # Y-axis data (maximum temperature)

# Call the function to create the linear regression plot
create_linear_regression_plot(x, y)
# Out:
# r-value: -0.73

# %%
# Linear regression on Southern Hemisphere
x = df_southern_hemisphere['Lat']  # X-axis data (latitude)
y = df_southern_hemisphere['Max Temp (°C)']  # Y-axis data (maximum temperature)

# Call the function to create the linear regression plot
create_linear_regression_plot(x, y, text_x=0.05, text_y=0.825)
# Out:
# r-value: 0.78

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Linear regression on Northern Hemisphere
x = df_northern_hemisphere['Lat']  # X-axis data (latitude)
y = df_northern_hemisphere['Humidity']  # Y-axis data (maximum temperature)

# Call the function to create the linear regression plot
create_linear_regression_plot(x, y, text_x=0.05, text_y=0.825)
# Out:
# r-value: 0.06

# %%
# Southern Hemisphere
# Linear regression on Southern Hemisphere
x = df_southern_hemisphere['Lat']  # X-axis data (latitude)
y = df_southern_hemisphere['Humidity']  # Y-axis data (maximum temperature)

# Call the function to create the linear regression plot
create_linear_regression_plot(x, y, text_x=0.05, text_y=0.825)
# Out:
# r-value: -0.14

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Linear regression on Northern Hemisphere
x = df_northern_hemisphere['Lat']  # X-axis data (latitude)
y = df_northern_hemisphere['Cloudiness']  # Y-axis data (maximum temperature)

# Call the function to create the linear regression plot
create_linear_regression_plot(x, y, text_x=0.05, text_y=0.825)
# Out:
# r-value: -0.02

# %%
# Southern Hemisphere
# Linear regression on Southern Hemisphere
x = df_southern_hemisphere['Lat']  # X-axis data (latitude)
y = df_southern_hemisphere['Cloudiness']  # Y-axis data (maximum temperature)

# Call the function to create the linear regression plot
create_linear_regression_plot(x, y, text_x=0.05, text_y=0.825)
# Out:
# r-value: -0.12

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# Linear regression on Northern Hemisphere
x = df_northern_hemisphere['Lat']  # X-axis data (latitude)
y = df_northern_hemisphere['Wind Speed']  # Y-axis data (maximum temperature)

# Call the function to create the linear regression plot
create_linear_regression_plot(x, y, text_x=0.05, text_y=0.825)
# Out:
# r-value: 0.04

# %%
# Southern Hemisphere
# Linear regression on Southern Hemisphere
x = df_southern_hemisphere['Lat']  # X-axis data (latitude)
y = df_southern_hemisphere['Wind Speed']  # Y-axis data (wind speed)

# Call the function to create the linear regression plot
create_linear_regression_plot(x, y, text_x=0.05, text_y=0.825)
# Out:
# r-value: -0.10

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
#
# 'Twas lovely!

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `df_city_data` DataFrame. The size of the point should be the humidity in each city.

# %%
# Configure the map plot
plot_map = df_city_data.hvplot.points(
    x='Lng',
    y='Lat',
    geo=True,
    tiles='OSM',
    c='City',
    size='Humidity',
    alpha=0.7,
    legend='right',
    title='City Humidity',
    xlabel='Longitude',
    ylabel='Latitude',
    hover_cols=['City', 'Humidity'],
    frame_height=500
)

# Display the plotted map
plot_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `df_city_data` DataFrame to find your ideal weather condition

# %%
# Ideal weather conditions temperature range
min_temp = 20  # Minimum temperature in Celsius
max_temp = 25  # Maximum temperature in Celsius

# Filter the DataFrame based on temperature range
df_ideal_conditions = df_city_data[(df_city_data['Max Temp (°C)'] >= min_temp) & (df_city_data['Max Temp (°C)'] <= max_temp)]

# Drop any rows with null values
df_ideal_conditions.dropna()

# Display sample data
df_ideal_conditions
# Out:
#                      City      Lat       Lng  Max Temp (°K)  Max Temp (°C)  \
# City_ID
# 1                   havre  49.5833    0.3333         297.37          24.22
# 2                thompson  55.7435  -97.8558         294.24          21.09
# 17               souillac -20.5167   57.5167         296.36          23.21
# 28       pontal do parana -25.6533  -48.5128         296.73          23.58
# 31                 faanui -16.4833 -151.7500         298.12          24.97
# ...                   ...      ...       ...            ...            ...
# 552               northam  51.0333   -4.2167         294.40          21.25
# 553                 prado -17.3411  -39.2208         297.53          24.38
# 554             mananjary -21.2167   48.3333         293.63          20.48
# 560                 ngama  11.7833   17.1667         297.14          23.99
# 561       santiago de cao  -7.9589  -79.2392         295.22          22.07
#
#          Humidity  Cloudiness  Wind Speed Country        Date  Quadratic_Fit  \
# City_ID
# 1              83           0        4.63      FR  1693769122      18.810168
# 2              46         100        6.69      CA  1693769018      15.223187
# 17             78          75        6.69      MU  1693769001      21.584497
# 28             81         100        2.06      BR  1693769126      19.037538
# 31             82         100        7.20      PF  1693769127      23.321227
# ...           ...         ...         ...     ...         ...            ...
# 552            84          89        3.13      GB  1693769237      18.014462
# 553            64         100        3.27      BR  1693769208      22.971255
# 554            85           0        0.93      MG  1693769237      21.259507
# 560            89         100        1.87      TD  1693769238      28.995002
# 561            83         100        3.60      PE  1693769239      26.229916
#
#          Distance from Quadratic
# City_ID
# 1                       5.409832
# 2                       5.866813
# 17                      1.625503
# 28                      4.542462
# 31                      1.648773
# ...                          ...
# 552                     3.235538
# 553                     1.408745
# 554                     0.779507
# 560                     5.005002
# 561                     4.159916
#
# [128 rows x 12 columns]

# %% [markdown]
# ### Step 3: Create a new DataFrame called `df_hotel`.

# %%
# Use the Pandas copy function to create DataFrame called df_hotel to store the city, country, coordinates, and humidity
df_hotel = df_ideal_conditions.copy()

# Set base URL for hotel search
base_url = "https://api.geoapify.com/v2/places"

# Iterate through the df_hotel DataFrame
for index, row in df_hotel.iterrows():
    # Get latitude and longitude from the DataFrame
    lat = row['Lat']
    lng = row['Lng']
    
    # Set parameters to search for a hotel
    params = {
        "text": "hotel",  # Search for hotels
        "lat": lat,  # Latitude of the location
        "lon": lng,  # Longitude of the location
        "type": "accommodation.hotel",  # Specify the type as "lodging" for hotels
        "apiKey": geoapify_key  # Replace with your actual API key
    }

    # Make an API request using the params dictionary
    response = requests.get(base_url, params=params)

    # Convert the API response to JSON format
    hotel_data = response.json()

    # Grab the first hotel from the results and store the name in the df_hotel DataFrame
    try:
        df_hotel.loc[index, "Hotel Name"] = hotel_data["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        df_hotel.loc[index, "Hotel Name"] = "No hotel found"

# Display sample data
df_hotel
# Out:
#                      City      Lat       Lng  Max Temp (°K)  Max Temp (°C)  \
# City_ID
# 1                   havre  49.5833    0.3333         297.37          24.22
# 2                thompson  55.7435  -97.8558         294.24          21.09
# 17               souillac -20.5167   57.5167         296.36          23.21
# 28       pontal do parana -25.6533  -48.5128         296.73          23.58
# 31                 faanui -16.4833 -151.7500         298.12          24.97
# ...                   ...      ...       ...            ...            ...
# 552               northam  51.0333   -4.2167         294.40          21.25
# 553                 prado -17.3411  -39.2208         297.53          24.38
# 554             mananjary -21.2167   48.3333         293.63          20.48
# 560                 ngama  11.7833   17.1667         297.14          23.99
# 561       santiago de cao  -7.9589  -79.2392         295.22          22.07
#
#          Humidity  Cloudiness  Wind Speed Country        Date  Quadratic_Fit  \
# City_ID
# 1              83           0        4.63      FR  1693769122      18.810168
# 2              46         100        6.69      CA  1693769018      15.223187
# 17             78          75        6.69      MU  1693769001      21.584497
# 28             81         100        2.06      BR  1693769126      19.037538
# 31             82         100        7.20      PF  1693769127      23.321227
# ...           ...         ...         ...     ...         ...            ...
# 552            84          89        3.13      GB  1693769237      18.014462
# 553            64         100        3.27      BR  1693769208      22.971255
# 554            85           0        0.93      MG  1693769237      21.259507
# 560            89         100        1.87      TD  1693769238      28.995002
# 561            83         100        3.60      PE  1693769239      26.229916
#
#          Distance from Quadratic                  Hotel Name
# City_ID
# 1                       5.409832  Le Relais des 2 Normandies
# 2                       5.866813                Thompson Inn
# 17                      1.625503            Hotel SkylineInn
# 28                      4.542462            Hotel Porto Fino
# 31                      1.648773                 Oa Oa Lodge
# ...                          ...                         ...
# 552                     3.235538         Durrant House Hotel
# 553                     1.408745    Pousada Recanto do Prado
# 554                     0.779507          Ideal Hotel Annexe
# 560                     5.005002                       الوطن
# 561                     4.159916           Hostal El Encanto
#
# [128 rows x 13 columns]

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set the search radius
radius = 10000  # 10,000 meters

# Iterate through the df_hotel DataFrame
for index, row in df_hotel.iterrows():
    # Get latitude and longitude from the DataFrame
    lat = row['Lat']
    lng = row['Lng']
    
    # Set parameters to search for a hotel
    params = {
        "text": "hotel",  # Search for hotels
        "lat": lat,  # Latitude of the location
        "lon": lng,  # Longitude of the location
        "type": "accommodation.hotel",  # Specify the type as "lodging" for hotels
        "radius": radius,  # Set the search radius
        "apiKey": geoapify_key  # Replace with your actual API key
    }

    # Make an API request using the params dictionary
    response = requests.get(base_url, params=params)

    # Convert the API response to JSON format
    hotel_data = response.json()

    # Grab the first hotel from the results and store the name in the df_hotel DataFrame
    try:
        df_hotel.loc[index, "Hotel Name"] = hotel_data["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        df_hotel.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{df_hotel.loc[index, 'City']} - nearest hotel: {df_hotel.loc[index, 'Hotel Name']}")

# Display sample data
df_hotel
# Out:
# havre - nearest hotel: Le Relais des 2 Normandies
# thompson - nearest hotel: Thompson Inn
# souillac - nearest hotel: Hotel SkylineInn
# pontal do parana - nearest hotel: Hotel Porto Fino
# faanui - nearest hotel: Oa Oa Lodge
# mahebourg - nearest hotel: Grand Bel Air
# arraial do cabo - nearest hotel: No hotel found
# moroni - nearest hotel: Ville de Moroni
# lodja - nearest hotel: 12 maisons Avenue
# torbay - nearest hotel: Hampton
# sassari - nearest hotel: ERSU
# honiara - nearest hotel: King Solomon Hotel
# quelimane - nearest hotel: Mabassa
# lagoa - nearest hotel: Casa da Madrinha
# zhangye - nearest hotel: Zhangye Hotel 张掖饭店
# am timan - nearest hotel: Nimla
# madang - nearest hotel: Madang Star International
# samarai - nearest hotel: Tree top resort
# bengkulu - nearest hotel: Dena Hotel
# port keats - nearest hotel: Banyan Farm Tourist Park
# antalaha - nearest hotel: Hôtel Florida
# didsbury - nearest hotel: Holly House Hotel
# bambous virieux - nearest hotel: Otentic Eco Tent Experience
# fortuna - nearest hotel: Comfort Inn & Suites Redwood Country
# teahupoo - nearest hotel: Vanira Lodge
# weligama - nearest hotel: Basecamp
# vaini - nearest hotel: Keleti International Resort
# bay roberts - nearest hotel: The Doctors House Inn & Spa
# caravelas - nearest hotel: Pousada dos Navegantes
# amuntai - nearest hotel: Grand Balqis Hotel
# ponta do sol - nearest hotel: Estalagem Ponta do Sol
# lata - nearest hotel: Residencial Botânico
# marawi - nearest hotel: Marawi Resort Hotel
# alyangula - nearest hotel: Pole 13 Camp
# pangani - nearest hotel: Not in use
# bambanglipuro - nearest hotel: Puri Ganjuran
# acari - nearest hotel: Hotel Capricho de Verano
# longyan - nearest hotel: No hotel found
# gorontalo - nearest hotel: Grand City Hotel
# maneadero - nearest hotel: Estero Beach Resort
# bekhtery - nearest hotel: Оазис
# vila franca do campo - nearest hotel: Vinha d'Areia Beach Hotel
# abengourou - nearest hotel: Relief
# avarua - nearest hotel: Paradise Inn
# kasama - nearest hotel: Kapishya Hot Springs
# saint-francois - nearest hotel: Chez Lily
# huangyan - nearest hotel: 橘都大酒店
# daru - nearest hotel: Kuki
# lasa - nearest hotel: Hotel "Drei Kreuz"
# san jose - nearest hotel: Hotel De Anza
# yumen - nearest hotel: Hotel that accepts tourists - big one with flashy lights
# lahad datu - nearest hotel: Silam Dynasty Hotel
# isangel - nearest hotel: Tanna Lodge
# kamaishi - nearest hotel: 釜石ベイシティホテル
# hobyo - nearest hotel: Kulmiye كولمية
# pointe-noire - nearest hotel: HÔTEL F.A.R.E
# portland - nearest hotel: the Hoxton
# crisan - nearest hotel: Delta Marina- pensiunea ***
# alofi - nearest hotel: Matavai Resort
# los llanos de aridane - nearest hotel: Valle Aridane
# richards bay - nearest hotel: Bon Hotel Waterfront
# kokopo - nearest hotel: Hotel Kokopo
# huarmey - nearest hotel: Hostal Santa Rosa
# kharabali - nearest hotel: No hotel found
# qobustan - nearest hotel: Ələt Otel
# yaan - nearest hotel: SG Resort
# meulaboh - nearest hotel: Hotel Meuligou
# sayyan - nearest hotel: الأندلس رويال
# japura - nearest hotel: Rafana Hotel
# takoradi - nearest hotel: Hillcrest
# beboto - nearest hotel: Auberge Princessa
# alice springs - nearest hotel: Aurora Alice Springs
# bowen - nearest hotel: Whitsunday Sands Resort
# mwinilunga - nearest hotel: Guest House le Manguier
# boyolangu - nearest hotel: Crown Victoria
# wattegama - nearest hotel: Hotel Silanrich
# monaragala - nearest hotel: Hotel Silanrich
# chibombo - nearest hotel: Ibis Gardens Reception
# acurenam - nearest hotel: Grand Hotel Djibloho
# dinard - nearest hotel: Les Tilleuls
# bandar - nearest hotel: Hotel Bilah
# amahai - nearest hotel: Onemay Hotel
# mumford - nearest hotel: Blue Diamond Beach Spa Resort
# anqing - nearest hotel: 安庆大酒店
# chase - nearest hotel: Quaaout Lodge
# tsnori - nearest hotel: ბორჯალი (Borjali)
# san vicente - nearest hotel: Los Lapachos
# moissala - nearest hotel: فندق سفاري
# yigou - nearest hotel: 鸿源大酒店
# liwale - nearest hotel: Masasi Guest House
# kharagauli - nearest hotel: Quality Inn Hotel
# belmonte - nearest hotel: Villa Tucano
# marivan - nearest hotel: هتل میران
# ponta delgada - nearest hotel: Hotel Talisman
# nador - nearest hotel: Hotel Lixus
# vurgun - nearest hotel: No hotel found
# soyo - nearest hotel: Hotel Maria Teres
# barcelos - nearest hotel: Hotel Dom Nuno
# peterborough - nearest hotel: Park Inn
# porto novo - nearest hotel: Hôtel 6500 CFA
# shimoda - nearest hotel: ホテルウラガ
# hellin - nearest hotel: Hotel Reina Victoria
# yuncheng - nearest hotel: 运城宾馆
# axim - nearest hotel: Axim Beach Hotel
# frutigen - nearest hotel: National
# yei - nearest hotel: New Tokyo
# kiunga - nearest hotel: Cloudlands Hotel
# carballo - nearest hotel: Hotel Balneario de Carballo
# camacupa - nearest hotel: No hotel found
# uspenka - nearest hotel: No hotel found
# poum - nearest hotel: Malabou Beach Hotel
# pisco - nearest hotel: La Portada
# yining - nearest hotel: 澄水洞宾馆
# mattru - nearest hotel: Dohas
# vallenar - nearest hotel: Hotel del Marqués
# ofunato - nearest hotel: No hotel found
# samfya - nearest hotel: Twemu Guest house
# ambilobe - nearest hotel: Hôtel National
# chicama - nearest hotel: Hotel Wasi
# puerto escondido - nearest hotel: Hotel Barlovento
# chiredzi - nearest hotel: Nesbitt Arms Hotel
# tual - nearest hotel: Suita
# kamina - nearest hotel: Hôtel DG
# northam - nearest hotel: Durrant House Hotel
# prado - nearest hotel: Pousada Recanto do Prado
# mananjary - nearest hotel: Ideal Hotel Annexe
# ngama - nearest hotel: الوطن
# santiago de cao - nearest hotel: Hostal El Encanto
#                      City      Lat       Lng  Max Temp (°K)  Max Temp (°C)  \
# City_ID
# 1                   havre  49.5833    0.3333         297.37          24.22
# 2                thompson  55.7435  -97.8558         294.24          21.09
# 17               souillac -20.5167   57.5167         296.36          23.21
# 28       pontal do parana -25.6533  -48.5128         296.73          23.58
# 31                 faanui -16.4833 -151.7500         298.12          24.97
# ...                   ...      ...       ...            ...            ...
# 552               northam  51.0333   -4.2167         294.40          21.25
# 553                 prado -17.3411  -39.2208         297.53          24.38
# 554             mananjary -21.2167   48.3333         293.63          20.48
# 560                 ngama  11.7833   17.1667         297.14          23.99
# 561       santiago de cao  -7.9589  -79.2392         295.22          22.07
#
#          Humidity  Cloudiness  Wind Speed Country        Date  Quadratic_Fit  \
# City_ID
# 1              83           0        4.63      FR  1693769122      18.810168
# 2              46         100        6.69      CA  1693769018      15.223187
# 17             78          75        6.69      MU  1693769001      21.584497
# 28             81         100        2.06      BR  1693769126      19.037538
# 31             82         100        7.20      PF  1693769127      23.321227
# ...           ...         ...         ...     ...         ...            ...
# 552            84          89        3.13      GB  1693769237      18.014462
# 553            64         100        3.27      BR  1693769208      22.971255
# 554            85           0        0.93      MG  1693769237      21.259507
# 560            89         100        1.87      TD  1693769238      28.995002
# 561            83         100        3.60      PE  1693769239      26.229916
#
#          Distance from Quadratic                  Hotel Name
# City_ID
# 1                       5.409832  Le Relais des 2 Normandies
# 2                       5.866813                Thompson Inn
# 17                      1.625503            Hotel SkylineInn
# 28                      4.542462            Hotel Porto Fino
# 31                      1.648773                 Oa Oa Lodge
# ...                          ...                         ...
# 552                     3.235538         Durrant House Hotel
# 553                     1.408745    Pousada Recanto do Prado
# 554                     0.779507          Ideal Hotel Annexe
# 560                     5.005002                       الوطن
# 561                     4.159916           Hostal El Encanto
#
# [128 rows x 13 columns]

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# Configure the map plot
plot_map_hotels = df_hotel.hvplot.points(
    x='Lng',
    y='Lat',
    geo=True,
    tiles='OSM',
    c='City',
    size='Humidity',
    alpha=0.7,
    legend='right',
    title='Hotel Locations and Humidity',
    xlabel='Longitude',
    ylabel='Latitude',
    hover_cols=['City', 'Hotel Name', 'Humidity'],
    frame_height=500
)

# Display the map
plot_map_hotels
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name)

# %%
# Defining functions

def create_linear_regression_plot(parameter_1, parameter_2, title, xlabel, ylabel, text_x=0.05, text_y=0.1):
    slope, intercept = np.polyfit(parameter_1, parameter_2, 1)
    r_value = np.corrcoef(parameter_1, parameter_2)[0, 1]

    plt.scatter(parameter_1, parameter_2)
    regression_line = slope * np.array(parameter_1) + intercept
    plt.plot(parameter_1, regression_line, color='red')

    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)

    equation = f'y = {slope:.2f}x + {intercept:.2f}'
    plt.text(text_x, text_y, equation, ha='left', va='bottom', transform=plt.gca().transAxes, fontsize=14, fontweight='normal', color='red')

    print(f'r-value: {r_value:.2f}')

def generate_plots(df, df_northern, df_southern, x_param, y_param):
    plt.figure(figsize=(15, 5))

    plt.subplot(1, 3, 1)
    create_linear_regression_plot(df[x_param], df[y_param], f'All Data: {x_param} vs {y_param}', x_param, y_param)

    plt.subplot(1, 3, 2)
    create_linear_regression_plot(df_northern[x_param], df_northern[y_param], f'Northern Hemisphere: {x_param} vs {y_param}', x_param, y_param)

    plt.subplot(1, 3, 3)
    create_linear_regression_plot(df_southern[x_param], df_southern[y_param], f'Southern Hemisphere: {x_param} vs {y_param}', x_param, y_param)

    plt.tight_layout()
    plt.show()

# %%
# Split the data into hemispheres
df_northern_hemisphere = df_city_data[df_city_data['Lat'] >= 0]
df_southern_hemisphere = df_city_data[df_city_data['Lat'] < 0]

# Generate plots for Latitude vs. Temperature
generate_plots(df_city_data, df_northern_hemisphere, df_southern_hemisphere, 'Lat', 'Max Temp (°C)')

# Generate plots for Latitude vs. Humidity
generate_plots(df_city_data, df_northern_hemisphere, df_southern_hemisphere, 'Lat', 'Humidity')

# Generate plots for Latitude vs. Cloudiness
generate_plots(df_city_data, df_northern_hemisphere, df_southern_hemisphere, 'Lat', 'Cloudiness')

# Generate plots for Latitude vs. Wind Speed
generate_plots(df_city_data, df_northern_hemisphere, df_southern_hemisphere, 'Lat', 'Wind Speed')
# Out:
# r-value: -0.20
# r-value: -0.73
# r-value: 0.78
# r-value: 0.02
# r-value: 0.06
# r-value: -0.14
# r-value: 0.01
# r-value: -0.02
# r-value: -0.12
# r-value: -0.05
# r-value: 0.04
# r-value: -0.10
